# %% [markdown]
# # <center> Topic 4. Neural Networks with PyTorch
#
# Сегодня вам предстоит на практике познакомиться с основными концептами обучения нейронных сетей с помощью [`PyTorch`](https://pytorch.org/).
#
# Для этого задания вам наверняка потребуется GPU, поэтому рекомендуется использовать [Google Colab](https://colab.research.google.com). Не забудьте поменять среду выполнения (Runtime -> Change Runtime Type и выбрать T4 GPU). Необходимые данные вы можете загрузить на Google Drive и затем использовать их внутри тетрадки.
#
# Для выполнения задания необходимо следовать по этой тетрадке сверху вниз и заполнять недостающее части кода или отвечать на заданные вопросы.

# %%
# Импортируем необходимые библиотеки
# Полезно все импорты держать рядом

import random
from os import listdir, path

import numpy as np
from matplotlib import pyplot
from PIL import Image
import torch
from torch import nn
from torch.optim import AdamW, Optimizer
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from tqdm.notebook import tqdm

# %matplotlib inline

# %%
# Зафиксируем сид для генератора случайных чисел
# Это полезно для воспроизводимости результатов

RANDOM_SEED = 0xC0FFEE

torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

# %%
# Определим девайс для вычислений

if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

print(device)
# Out:
# cuda

# %% [markdown]
# # This Cat does not Exist
#
# Будем создавать изображения котов, которых не существует!

# %%
# Определим несколько вспомогательных функций


def visualize_images(imgs: torch.Tensor, rows: int = 2):
    imgs = (imgs.transpose(1, 3) + 1) / 2
    cols = imgs.shape[0] // 2 + (imgs.shape[0] % 2)

    # Create a figure to display the images
    fig, axes = pyplot.subplots(rows, cols, figsize=(5, 5))

    # Iterate over the images and display them
    for i, ax in enumerate(axes.flat):
        if i < len(imgs):
            # Display the image
            ax.imshow(imgs[i].cpu().numpy())
            ax.axis("off")  # Turn off axis labels

    # Adjust spacing between images
    pyplot.tight_layout()
    pyplot.axis("off")
    pyplot.show()

# %% [markdown]
# ## Датасет
#
# Реализуем класс для нашего датасета. В нашем датасете не так много картинок, поэтому может сделать Map-Style датасет. Для этого необходимо определить функции `__getitem__` и `__len__`. Первая отвечает за загрузку отдельного элемента датасета, изображения, а вторая возвращает длину датасета.

# %%
# !unzip /content/cat_136.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cat_136/flickr_cat_000168.jpg
#   inflating: cat_136/flickr_cat_000169.jpg
#   inflating: cat_136/flickr_cat_000170.jpg
#   inflating: cat_136/flickr_cat_000171.jpg
#   inflating: cat_136/flickr_cat_000172.jpg
#   inflating: cat_136/flickr_cat_000173.jpg
#   inflating: cat_136/flickr_cat_000178.jpg
#   inflating: cat_136/flickr_cat_000179.jpg
#   inflating: cat_136/flickr_cat_000181.jpg
#   inflating: cat_136/flickr_cat_000185.jpg
#   inflating: cat_136/flickr_cat_000186.jpg
#   inflating: cat_136/flickr_cat_000187.jpg
#   inflating: cat_136/flickr_cat_000188.jpg
#   inflating: cat_136/flickr_cat_000189.jpg
#   inflating: cat_136/flickr_cat_000190.jpg
#   inflating: cat_136/flickr_cat_000192.jpg
#   inflating: cat_136/flickr_cat_000193.jpg
#   inflating: cat_136/flickr_cat_000194.jpg
#   inflating: cat_136/flickr_cat_000195.jpg
#   inflating: cat_136/flickr_cat_000196.jpg
#   inflating: cat_136/flickr_cat_000197.jpg
#   inflating: cat_136/flickr_cat_000198.jpg
#   inflating: cat_136/flickr_cat_000199.jpg
#   inflating: cat_136/flickr_cat_000200.jpg
#   inflating: cat_136/flickr_cat_000201.jpg
#   inflating: cat_136/flickr_cat_000202.jpg
#   inflating: cat_136/flickr_cat_000203.jpg
#   inflating: cat_136/flickr_cat_000204.jpg
#   inflating: cat_136/flickr_cat_000205.jpg
#   inflating: cat_136/flickr_cat_000206.jpg
#   inflating: cat_136/flickr_cat_000207.jpg
#   inflating: cat_136/flickr_cat_000209.jpg
#   inflating: cat_136/flickr_cat_000210.jpg
#   inflating: cat_136/flickr_cat_000211.jpg
#   inflating: cat_136/flickr_cat_000212.jpg
#   inflating: cat_136/flickr_cat_000213.jpg
#   inflating: cat_136/flickr_cat_000214.jpg
#   inflating: cat_136/flickr_cat_000215.jpg
#   inflating: cat_136/flickr_cat_000217.jpg
#   inflating: cat_136/flickr_cat_000218.jpg
#   inflating: cat_136/flickr_cat_000219.jpg
#   inflating: cat_136/flickr_cat_000220.jpg
#   inflating: cat_136/flickr_cat_000221.jpg
#   inflating: cat_136/flickr_cat_000222.jpg
#   inflating: cat_136/flickr_cat_000223.jpg
#   inflating: cat_136/flickr_cat_000224.jpg
#   inflating: cat_136/flickr_cat_000225.jpg
#   inflating: cat_136/flickr_cat_000227.jpg
#   inflating: cat_136/flickr_cat_000228.jpg
#   inflating: cat_136/flickr_cat_000229.jpg
#   inflating: cat_136/flickr_cat_000231.jpg
#   inflating: cat_136/flickr_cat_000234.jpg
#   inflating: cat_136/flickr_cat_000235.jpg
#   inflating: cat_136/flickr_cat_000237.jpg
#   inflating: cat_136/flickr_cat_000239.jpg
#   inflating: cat_136/flickr_cat_000240.jpg
#   inflating: cat_136/flickr_cat_000241.jpg
#   inflating: cat_136/flickr_cat_000242.jpg
#   inflating: cat_136/flickr_cat_000243.jpg
#   inflating: cat_136/flickr_cat_000244.jpg
#   inflating: cat_136/flickr_cat_000245.jpg
#   inflating: cat_136/flickr_cat_000246.jpg
#   inflating: cat_136/flickr_cat_000247.jpg
#   inflating: cat_136/flickr_cat_000248.jpg
#   inflating: cat_136/flickr_cat_000249.jpg
#   inflating: cat_136/flickr_cat_000250.jpg
#   inflating: cat_136/flickr_cat_000251.jpg
#   inflating: cat_136/flickr_cat_000252.jpg
#   inflating: cat_136/flickr_cat_000254.jpg
#   inflating: cat_136/flickr_cat_000255.jpg
#   inflating: cat_136/flickr_cat_000256.jpg
#   inflating: cat_136/flickr_cat_000257.jpg
#   inflating: cat_136/flickr_cat_000258.jpg
#   inflating: cat_136/flickr_cat_000259.jpg
#   inflating: cat_136/flickr_cat_000260.jpg
#   inflating: cat_136/flickr_cat_000261.jpg
#   inflating: cat_136/flickr_cat_000262.jpg
#   inflating: cat_136/flickr_cat_000263.jpg
#   inflating: cat_136/flickr_cat_000264.jpg
#   inflating: cat_136/flickr_cat_000266.jpg
#   inflating: cat_136/flickr_cat_000267.jpg
#   inflating: cat_136/flickr_cat_000268.jpg
#   inflating: cat_136/flickr_cat_000269.jpg
#   inflating: cat_136/flickr_cat_000270.jpg
#   inflating: cat_136/flickr_cat_000271.jpg
#   inflating: cat_136/flickr_cat_000272.jpg
#   inflating: cat_136/flickr_cat_000273.jpg
#   inflating: cat_136/flickr_cat_000274.jpg
#   inflating: cat_136/flickr_cat_000275.jpg
#   inflating: cat_136/flickr_cat_000276.jpg
#   inflating: cat_136/flickr_cat_000277.jpg
#   inflating: cat_136/flickr_cat_000278.jpg
#   inflating: cat_136/flickr_cat_000279.jpg
#   inflating: cat_136/flickr_cat_000280.jpg
#   inflating: cat_136/flickr_cat_000281.jpg
#   inflating: cat_136/flickr_cat_000282.jpg
#   inflating: cat_136/flickr_cat_000284.jpg
#   inflating: cat_136/flickr_cat_000285.jpg
#   inflating: cat_136/flickr_cat_000286.jpg
#   inflating: cat_136/flickr_cat_000288.jpg
#   inflating: cat_136/flickr_cat_000289.jpg
#   inflating: cat_136/flickr_cat_000290.jpg
#   inflating: cat_136/flickr_cat_000291.jpg
#   inflating: cat_136/flickr_cat_000293.jpg
#   inflating: cat_136/flickr_cat_000294.jpg
#   inflating: cat_136/flickr_cat_000295.jpg
#   inflating: cat_136/flickr_cat_000296.jpg
#   inflating: cat_136/flickr_cat_000297.jpg
#   inflating: cat_136/flickr_cat_000298.jpg
#   inflating: cat_136/flickr_cat_000299.jpg
#   inflating: cat_136/flickr_cat_000300.jpg
#   inflating: cat_136/flickr_cat_000301.jpg
#   inflating: cat_136/flickr_cat_000302.jpg
#   inflating: cat_136/flickr_cat_000303.jpg
#   inflating: cat_136/flickr_cat_000304.jpg
#   inflating: cat_136/flickr_cat_000305.jpg
#   inflating: cat_136/flickr_cat_000306.jpg
#   inflating: cat_136/flickr_cat_000307.jpg
#   inflating: cat_136/flickr_cat_000308.jpg
#   inflating: cat_136/flickr_cat_000309.jpg
#   inflating: cat_136/flickr_cat_000310.jpg
#   inflating: cat_136/flickr_cat_000312.jpg
#   inflating: cat_136/flickr_cat_000313.jpg
#   inflating: cat_136/flickr_cat_000315.jpg
#   inflating: cat_136/flickr_cat_000316.jpg
#   inflating: cat_136/flickr_cat_000317.jpg
#   inflating: cat_136/flickr_cat_000318.jpg
#   inflating: cat_136/flickr_cat_000319.jpg
#   inflating: cat_136/flickr_cat_000321.jpg
#   inflating: cat_136/flickr_cat_000322.jpg
#   inflating: cat_136/flickr_cat_000323.jpg
#   inflating: cat_136/flickr_cat_000324.jpg
#   inflating: cat_136/flickr_cat_000325.jpg
#   inflating: cat_136/flickr_cat_000326.jpg
#   inflating: cat_136/flickr_cat_000327.jpg
#   inflating: cat_136/flickr_cat_000328.jpg
#   inflating: cat_136/flickr_cat_000329.jpg
#   inflating: cat_136/flickr_cat_000330.jpg
#   inflating: cat_136/flickr_cat_000331.jpg
#   inflating: cat_136/flickr_cat_000332.jpg
#   inflating: cat_136/flickr_cat_000333.jpg
#   inflating: cat_136/flickr_cat_000334.jpg
#   inflating: cat_136/flickr_cat_000335.jpg
#   inflating: cat_136/flickr_cat_000336.jpg
#   inflating: cat_136/flickr_cat_000337.jpg
#   inflating: cat_136/flickr_cat_000338.jpg
#   inflating: cat_136/flickr_cat_000339.jpg
#   inflating: cat_136/flickr_cat_000340.jpg
#   inflating: cat_136/flickr_cat_000342.jpg
#   inflating: cat_136/flickr_cat_000343.jpg
#   inflating: cat_136/flickr_cat_000344.jpg
#   inflating: cat_136/flickr_cat_000345.jpg
#   inflating: cat_136/flickr_cat_000346.jpg
#   inflating: cat_136/flickr_cat_000347.jpg
#   inflating: cat_136/flickr_cat_000348.jpg
#   inflating: cat_136/flickr_cat_000349.jpg
#   inflating: cat_136/flickr_cat_000352.jpg
#   inflating: cat_136/flickr_cat_000353.jpg
#   inflating: cat_136/flickr_cat_000354.jpg
#   inflating: cat_136/flickr_cat_000355.jpg
#   inflating: cat_136/flickr_cat_000356.jpg
#   inflating: cat_136/flickr_cat_000357.jpg
#   inflating: cat_136/flickr_cat_000358.jpg
#   inflating: cat_136/flickr_cat_000359.jpg
#   inflating: cat_136/flickr_cat_000360.jpg
#   inflating: cat_136/flickr_cat_000361.jpg
#   inflating: cat_136/flickr_cat_000362.jpg
#   inflating: cat_136/flickr_cat_000363.jpg
#   inflating: cat_136/flickr_cat_000364.jpg
#   inflating: cat_136/flickr_cat_000365.jpg
#   inflating: cat_136/flickr_cat_000366.jpg
#   inflating: cat_136/flickr_cat_000367.jpg
#   inflating: cat_136/flickr_cat_000369.jpg
#   inflating: cat_136/flickr_cat_000370.jpg
#   inflating: cat_136/flickr_cat_000371.jpg
#   inflating: cat_136/flickr_cat_000373.jpg
#   inflating: cat_136/flickr_cat_000374.jpg
#   inflating: cat_136/flickr_cat_000375.jpg
#   inflating: cat_136/flickr_cat_000376.jpg
#   inflating: cat_136/flickr_cat_000378.jpg
#   inflating: cat_136/flickr_cat_000379.jpg
#   inflating: cat_136/flickr_cat_000380.jpg
#   inflating: cat_136/flickr_cat_000381.jpg
#   inflating: cat_136/flickr_cat_000382.jpg
#   inflating: cat_136/flickr_cat_000383.jpg
#   inflating: cat_136/flickr_cat_000384.jpg
#   inflating: cat_136/flickr_cat_000385.jpg
#   inflating: cat_136/flickr_cat_000386.jpg
#   inflating: cat_136/flickr_cat_000388.jpg
#   inflating: cat_136/flickr_cat_000389.jpg
#   inflating: cat_136/flickr_cat_000390.jpg
#   inflating: cat_136/flickr_cat_000391.jpg
#   inflating: cat_136/flickr_cat_000392.jpg
#   inflating: cat_136/flickr_cat_000393.jpg
#   inflating: cat_136/flickr_cat_000394.jpg
#   inflating: cat_136/flickr_cat_000395.jpg
#   inflating: cat_136/flickr_cat_000396.jpg
#   inflating: cat_136/flickr_cat_000397.jpg
#   inflating: cat_136/flickr_cat_000398.jpg
#   inflating: cat_136/flickr_cat_000399.jpg
#   inflating: cat_136/flickr_cat_000400.jpg
#   inflating: cat_136/flickr_cat_000401.jpg
#   inflating: cat_136/flickr_cat_000402.jpg
#   inflating: cat_136/flickr_cat_000403.jpg
#   inflating: cat_136/flickr_cat_000404.jpg
#   inflating: cat_136/flickr_cat_000405.jpg
#   inflating: cat_136/flickr_cat_000406.jpg
#   inflating: cat_136/flickr_cat_000407.jpg
#   inflating: cat_136/flickr_cat_000408.jpg
#   inflating: cat_136/flickr_cat_000409.jpg
#   inflating: cat_136/flickr_cat_000410.jpg
#   inflating: cat_136/flickr_cat_000411.jpg
#   inflating: cat_136/flickr_cat_000412.jpg
#   inflating: cat_136/flickr_cat_000413.jpg
#   inflating: cat_136/flickr_cat_000414.jpg
#   inflating: cat_136/flickr_cat_000415.jpg
#   inflating: cat_136/flickr_cat_000416.jpg
#   inflating: cat_136/flickr_cat_000417.jpg
#   inflating: cat_136/flickr_cat_000420.jpg
#   inflating: cat_136/flickr_cat_000421.jpg
#   inflating: cat_136/flickr_cat_000422.jpg
#   inflating: cat_136/flickr_cat_000423.jpg
#   inflating: cat_136/flickr_cat_000424.jpg
#   inflating: cat_136/flickr_cat_000425.jpg
#   inflating: cat_136/flickr_cat_000426.jpg
#   inflating: cat_136/flickr_cat_000427.jpg
#   inflating: cat_136/flickr_cat_000428.jpg
#   inflating: cat_136/flickr_cat_000429.jpg
#   inflating: cat_136/flickr_cat_000430.jpg
#   inflating: cat_136/flickr_cat_000431.jpg
#   inflating: cat_136/flickr_cat_000432.jpg
#   inflating: cat_136/flickr_cat_000433.jpg
#   inflating: cat_136/flickr_cat_000434.jpg
#   inflating: cat_136/flickr_cat_000435.jpg
#   inflating: cat_136/flickr_cat_000436.jpg
#   inflating: cat_136/flickr_cat_000438.jpg
#   inflating: cat_136/flickr_cat_000439.jpg
#   inflating: cat_136/flickr_cat_000440.jpg
#   inflating: cat_136/flickr_cat_000442.jpg
#   inflating: cat_136/flickr_cat_000443.jpg
#   inflating: cat_136/flickr_cat_000444.jpg
#   inflating: cat_136/flickr_cat_000445.jpg
#   inflating: cat_136/flickr_cat_000447.jpg
#   inflating: cat_136/flickr_cat_000448.jpg
#   inflating: cat_136/flickr_cat_000449.jpg
#   inflating: cat_136/flickr_cat_000450.jpg
#   inflating: cat_136/flickr_cat_000451.jpg
#   inflating: cat_136/flickr_cat_000452.jpg
#   inflating: cat_136/flickr_cat_000453.jpg
#   inflating: cat_136/flickr_cat_000454.jpg
#   inflating: cat_136/flickr_cat_000455.jpg
#   inflating: cat_136/flickr_cat_000456.jpg
#   inflating: cat_136/flickr_cat_000457.jpg
#   inflating: cat_136/flickr_cat_000458.jpg
#   inflating: cat_136/flickr_cat_000459.jpg
#   inflating: cat_136/flickr_cat_000460.jpg
#   inflating: cat_136/flickr_cat_000461.jpg
#   inflating: cat_136/flickr_cat_000462.jpg
#   inflating: cat_136/flickr_cat_000463.jpg
#   inflating: cat_136/flickr_cat_000464.jpg
#   inflating: cat_136/flickr_cat_000465.jpg
#   inflating: cat_136/flickr_cat_000466.jpg
#   inflating: cat_136/flickr_cat_000467.jpg
#   inflating: cat_136/flickr_cat_000468.jpg
#   inflating: cat_136/flickr_cat_000469.jpg
#   inflating: cat_136/flickr_cat_000470.jpg
#   inflating: cat_136/flickr_cat_000471.jpg
#   inflating: cat_136/flickr_cat_000472.jpg
#   inflating: cat_136/flickr_cat_000473.jpg
#   inflating: cat_136/flickr_cat_000474.jpg
#   inflating: cat_136/flickr_cat_000475.jpg
#   inflating: cat_136/flickr_cat_000476.jpg
#   inflating: cat_136/flickr_cat_000477.jpg
#   inflating: cat_136/flickr_cat_000478.jpg
#   inflating: cat_136/flickr_cat_000479.jpg
#   inflating: cat_136/flickr_cat_000480.jpg
#   inflating: cat_136/flickr_cat_000481.jpg
#   inflating: cat_136/flickr_cat_000482.jpg
#   inflating: cat_136/flickr_cat_000483.jpg
#   inflating: cat_136/flickr_cat_000484.jpg
#   inflating: cat_136/flickr_cat_000485.jpg
#   inflating: cat_136/flickr_cat_000486.jpg
#   inflating: cat_136/flickr_cat_000487.jpg
#   inflating: cat_136/flickr_cat_000488.jpg
#   inflating: cat_136/flickr_cat_000489.jpg
#   inflating: cat_136/flickr_cat_000490.jpg
#   inflating: cat_136/flickr_cat_000491.jpg
#   inflating: cat_136/flickr_cat_000492.jpg
#   inflating: cat_136/flickr_cat_000493.jpg
#   inflating: cat_136/flickr_cat_000494.jpg
#   inflating: cat_136/flickr_cat_000496.jpg
#   inflating: cat_136/flickr_cat_000497.jpg
#   inflating: cat_136/flickr_cat_000498.jpg
#   inflating: cat_136/flickr_cat_000499.jpg
#   inflating: cat_136/flickr_cat_000500.jpg
#   inflating: cat_136/flickr_cat_000501.jpg
#   inflating: cat_136/flickr_cat_000502.jpg
#   inflating: cat_136/flickr_cat_000503.jpg
#   inflating: cat_136/flickr_cat_000504.jpg
#   inflating: cat_136/flickr_cat_000505.jpg
#   inflating: cat_136/flickr_cat_000506.jpg
#   inflating: cat_136/flickr_cat_000507.jpg
#   inflating: cat_136/flickr_cat_000508.jpg
#   inflating: cat_136/flickr_cat_000509.jpg
#   inflating: cat_136/flickr_cat_000510.jpg
#   inflating: cat_136/flickr_cat_000511.jpg
#   inflating: cat_136/flickr_cat_000512.jpg
#   inflating: cat_136/flickr_cat_000513.jpg
#   inflating: cat_136/flickr_cat_000515.jpg
#   inflating: cat_136/flickr_cat_000516.jpg
#   inflating: cat_136/flickr_cat_000517.jpg
#   inflating: cat_136/flickr_cat_000518.jpg
#   inflating: cat_136/flickr_cat_000519.jpg
#   inflating: cat_136/flickr_cat_000520.jpg
#   inflating: cat_136/flickr_cat_000521.jpg
#   inflating: cat_136/flickr_cat_000523.jpg
#   inflating: cat_136/flickr_cat_000524.jpg
#   inflating: cat_136/flickr_cat_000525.jpg
#   inflating: cat_136/flickr_cat_000527.jpg
#   inflating: cat_136/flickr_cat_000528.jpg
#   inflating: cat_136/flickr_cat_000530.jpg
#   inflating: cat_136/flickr_cat_000531.jpg
#   inflating: cat_136/flickr_cat_000532.jpg
#   inflating: cat_136/flickr_cat_000533.jpg
#   inflating: cat_136/flickr_cat_000537.jpg
#   inflating: cat_136/flickr_cat_000538.jpg
#   inflating: cat_136/flickr_cat_000539.jpg
#   inflating: cat_136/flickr_cat_000540.jpg
#   inflating: cat_136/flickr_cat_000541.jpg
#   inflating: cat_136/flickr_cat_000542.jpg
#   inflating: cat_136/flickr_cat_000543.jpg
#   inflating: cat_136/flickr_cat_000544.jpg
#   inflating: cat_136/flickr_cat_000545.jpg
#   inflating: cat_136/flickr_cat_000546.jpg
#   inflating: cat_136/flickr_cat_000547.jpg
#   inflating: cat_136/flickr_cat_000548.jpg
#   inflating: cat_136/flickr_cat_000549.jpg
#   inflating: cat_136/flickr_cat_000550.jpg
#   inflating: cat_136/flickr_cat_000551.jpg
#   inflating: cat_136/flickr_cat_000552.jpg
#   inflating: cat_136/flickr_cat_000553.jpg
#   inflating: cat_136/flickr_cat_000555.jpg
#   inflating: cat_136/flickr_cat_000556.jpg
#   inflating: cat_136/flickr_cat_000558.jpg
#   inflating: cat_136/flickr_cat_000559.jpg
#   inflating: cat_136/flickr_cat_000561.jpg
#   inflating: cat_136/flickr_cat_000562.jpg
#   inflating: cat_136/flickr_cat_000563.jpg
#   inflating: cat_136/flickr_cat_000564.jpg
#   inflating: cat_136/flickr_cat_000565.jpg
#   inflating: cat_136/flickr_cat_000566.jpg
#   inflating: cat_136/flickr_cat_000567.jpg
#   inflating: cat_136/flickr_cat_000568.jpg
#   inflating: cat_136/flickr_cat_000569.jpg
#   inflating: cat_136/flickr_cat_000571.jpg
#   inflating: cat_136/flickr_cat_000572.jpg
#   inflating: cat_136/flickr_cat_000573.jpg
#   inflating: cat_136/flickr_cat_000574.jpg
#   inflating: cat_136/flickr_cat_000576.jpg
#   inflating: cat_136/flickr_cat_000577.jpg
#   inflating: cat_136/flickr_cat_000578.jpg
#   inflating: cat_136/flickr_cat_000579.jpg
#   inflating: cat_136/flickr_cat_000580.jpg
#   inflating: cat_136/flickr_cat_000581.jpg
#   inflating: cat_136/flickr_cat_000582.jpg
#   inflating: cat_136/flickr_cat_000583.jpg
#   inflating: cat_136/flickr_cat_000584.jpg
#   inflating: cat_136/flickr_cat_000586.jpg
#   inflating: cat_136/flickr_cat_000587.jpg
#   inflating: cat_136/flickr_cat_000588.jpg
#   inflating: cat_136/flickr_cat_000589.jpg
#   inflating: cat_136/flickr_cat_000590.jpg
#   inflating: cat_136/flickr_cat_000591.jpg
#   inflating: cat_136/flickr_cat_000593.jpg
#   inflating: cat_136/flickr_cat_000594.jpg
#   inflating: cat_136/flickr_cat_000595.jpg
#   inflating: cat_136/flickr_cat_000596.jpg
#   inflating: cat_136/flickr_cat_000597.jpg
#   inflating: cat_136/flickr_cat_000598.jpg
#   inflating: cat_136/flickr_cat_000600.jpg
#   inflating: cat_136/flickr_cat_000601.jpg
#   inflating: cat_136/flickr_cat_000602.jpg
#   inflating: cat_136/flickr_cat_000603.jpg
#   inflating: cat_136/flickr_cat_000604.jpg
#   inflating: cat_136/flickr_cat_000605.jpg
#   inflating: cat_136/flickr_cat_000606.jpg
#   inflating: cat_136/flickr_cat_000607.jpg
#   inflating: cat_136/flickr_cat_000609.jpg
#   inflating: cat_136/flickr_cat_000611.jpg
#   inflating: cat_136/flickr_cat_000612.jpg
#   inflating: cat_136/flickr_cat_000613.jpg
#   inflating: cat_136/flickr_cat_000615.jpg
#   inflating: cat_136/flickr_cat_000616.jpg
#   inflating: cat_136/flickr_cat_000617.jpg
#   inflating: cat_136/flickr_cat_000618.jpg
#   inflating: cat_136/flickr_cat_000619.jpg
#   inflating: cat_136/flickr_cat_000620.jpg
#   inflating: cat_136/flickr_cat_000621.jpg
#   inflating: cat_136/flickr_cat_000622.jpg
#   inflating: cat_136/flickr_cat_000623.jpg
#   inflating: cat_136/flickr_cat_000624.jpg
#   inflating: cat_136/flickr_cat_000625.jpg
#   inflating: cat_136/flickr_cat_000626.jpg
#   inflating: cat_136/flickr_cat_000627.jpg
#   inflating: cat_136/flickr_cat_000630.jpg
#   inflating: cat_136/flickr_cat_000631.jpg
#   inflating: cat_136/flickr_cat_000632.jpg
#   inflating: cat_136/flickr_cat_000633.jpg
#   inflating: cat_136/flickr_cat_000634.jpg
#   inflating: cat_136/flickr_cat_000636.jpg
#   inflating: cat_136/flickr_cat_000638.jpg
#   inflating: cat_136/flickr_cat_000639.jpg
#   inflating: cat_136/flickr_cat_000640.jpg
#   inflating: cat_136/flickr_cat_000641.jpg
#   inflating: cat_136/flickr_cat_000642.jpg
#   inflating: cat_136/flickr_cat_000643.jpg
#   inflating: cat_136/flickr_cat_000644.jpg
#   inflating: cat_136/flickr_cat_000645.jpg
#   inflating: cat_136/flickr_cat_000646.jpg
#   inflating: cat_136/flickr_cat_000647.jpg
#   inflating: cat_136/flickr_cat_000648.jpg
#   inflating: cat_136/flickr_cat_000649.jpg
#   inflating: cat_136/flickr_cat_000650.jpg
#   inflating: cat_136/flickr_cat_000651.jpg
#   inflating: cat_136/flickr_cat_000652.jpg
#   inflating: cat_136/flickr_cat_000654.jpg
#   inflating: cat_136/flickr_cat_000655.jpg
#   inflating: cat_136/flickr_cat_000657.jpg
#   inflating: cat_136/flickr_cat_000658.jpg
#   inflating: cat_136/flickr_cat_000659.jpg
#   inflating: cat_136/flickr_cat_000660.jpg
#   inflating: cat_136/flickr_cat_000661.jpg
#   inflating: cat_136/flickr_cat_000662.jpg
#   inflating: cat_136/flickr_cat_000663.jpg
#   inflating: cat_136/flickr_cat_000664.jpg
#   inflating: cat_136/flickr_cat_000665.jpg
#   inflating: cat_136/flickr_cat_000666.jpg
#   inflating: cat_136/flickr_cat_000667.jpg
#   inflating: cat_136/flickr_cat_000668.jpg
#   inflating: cat_136/flickr_cat_000669.jpg
#   inflating: cat_136/flickr_cat_000670.jpg
#   inflating: cat_136/flickr_cat_000671.jpg
#   inflating: cat_136/flickr_cat_000672.jpg
#   inflating: cat_136/flickr_cat_000673.jpg
#   inflating: cat_136/flickr_cat_000674.jpg
#   inflating: cat_136/flickr_cat_000675.jpg
#   inflating: cat_136/flickr_cat_000677.jpg
#   inflating: cat_136/flickr_cat_000678.jpg
#   inflating: cat_136/flickr_cat_000679.jpg
#   inflating: cat_136/flickr_cat_000680.jpg
#   inflating: cat_136/flickr_cat_000681.jpg
#   inflating: cat_136/flickr_cat_000682.jpg
#   inflating: cat_136/flickr_cat_000683.jpg
#   inflating: cat_136/flickr_cat_000684.jpg
#   inflating: cat_136/flickr_cat_000685.jpg
#   inflating: cat_136/flickr_cat_000686.jpg
#   inflating: cat_136/flickr_cat_000687.jpg
#   inflating: cat_136/flickr_cat_000689.jpg
#   inflating: cat_136/flickr_cat_000690.jpg
#   inflating: cat_136/flickr_cat_000691.jpg
#   inflating: cat_136/flickr_cat_000692.jpg
#   inflating: cat_136/flickr_cat_000693.jpg
#   inflating: cat_136/flickr_cat_000694.jpg
#   inflating: cat_136/flickr_cat_000695.jpg
#   inflating: cat_136/flickr_cat_000696.jpg
#   inflating: cat_136/flickr_cat_000697.jpg
#   inflating: cat_136/flickr_cat_000698.jpg
#   inflating: cat_136/flickr_cat_000699.jpg
#   inflating: cat_136/flickr_cat_000700.jpg
#   inflating: cat_136/flickr_cat_000701.jpg
#   inflating: cat_136/flickr_cat_000702.jpg
#   inflating: cat_136/flickr_cat_000703.jpg
#   inflating: cat_136/flickr_cat_000704.jpg
#   inflating: cat_136/flickr_cat_000705.jpg
#   inflating: cat_136/flickr_cat_000706.jpg
#   inflating: cat_136/flickr_cat_000707.jpg
#   inflating: cat_136/flickr_cat_000708.jpg
#   inflating: cat_136/flickr_cat_000710.jpg
#   inflating: cat_136/flickr_cat_000711.jpg
#   inflating: cat_136/flickr_cat_000712.jpg
#   inflating: cat_136/flickr_cat_000713.jpg
#   inflating: cat_136/flickr_cat_000715.jpg
#   inflating: cat_136/flickr_cat_000716.jpg
#   inflating: cat_136/flickr_cat_000717.jpg
#   inflating: cat_136/flickr_cat_000718.jpg
#   inflating: cat_136/flickr_cat_000719.jpg
#   inflating: cat_136/flickr_cat_000720.jpg
#   inflating: cat_136/flickr_cat_000721.jpg
#   inflating: cat_136/flickr_cat_000722.jpg
#   inflating: cat_136/flickr_cat_000723.jpg
#   inflating: cat_136/flickr_cat_000724.jpg
#   inflating: cat_136/flickr_cat_000725.jpg
#   inflating: cat_136/flickr_cat_000726.jpg
#   inflating: cat_136/flickr_cat_000727.jpg
#   inflating: cat_136/flickr_cat_000728.jpg
#   inflating: cat_136/flickr_cat_000729.jpg
#   inflating: cat_136/flickr_cat_000730.jpg
#   inflating: cat_136/flickr_cat_000731.jpg
#   inflating: cat_136/flickr_cat_000732.jpg
#   inflating: cat_136/flickr_cat_000733.jpg
#   inflating: cat_136/flickr_cat_000734.jpg
#   inflating: cat_136/flickr_cat_000735.jpg
#   inflating: cat_136/flickr_cat_000736.jpg
#   inflating: cat_136/flickr_cat_000737.jpg
#   inflating: cat_136/flickr_cat_000738.jpg
#   inflating: cat_136/flickr_cat_000739.jpg
#   inflating: cat_136/flickr_cat_000740.jpg
#   inflating: cat_136/flickr_cat_000741.jpg
#   inflating: cat_136/flickr_cat_000742.jpg
#   inflating: cat_136/flickr_cat_000743.jpg
#   inflating: cat_136/flickr_cat_000744.jpg
#   inflating: cat_136/flickr_cat_000745.jpg
#   inflating: cat_136/flickr_cat_000748.jpg
#   inflating: cat_136/flickr_cat_000749.jpg
#   inflating: cat_136/flickr_cat_000750.jpg
#   inflating: cat_136/flickr_cat_000752.jpg
#   inflating: cat_136/flickr_cat_000753.jpg
#   inflating: cat_136/flickr_cat_000754.jpg
#   inflating: cat_136/flickr_cat_000755.jpg
#   inflating: cat_136/flickr_cat_000756.jpg
#   inflating: cat_136/flickr_cat_000757.jpg
#   inflating: cat_136/flickr_cat_000758.jpg
#   inflating: cat_136/flickr_cat_000760.jpg
#   inflating: cat_136/flickr_cat_000762.jpg
#   inflating: cat_136/flickr_cat_000763.jpg
#   inflating: cat_136/flickr_cat_000764.jpg
#   inflating: cat_136/flickr_cat_000765.jpg
#   inflating: cat_136/flickr_cat_000767.jpg
#   inflating: cat_136/flickr_cat_000768.jpg
#   inflating: cat_136/flickr_cat_000770.jpg
#   inflating: cat_136/flickr_cat_000771.jpg
#   inflating: cat_136/flickr_cat_000772.jpg
#   inflating: cat_136/flickr_cat_000773.jpg
#   inflating: cat_136/flickr_cat_000774.jpg
#   inflating: cat_136/flickr_cat_000775.jpg
#   inflating: cat_136/flickr_cat_000776.jpg
#   inflating: cat_136/flickr_cat_000777.jpg
#   inflating: cat_136/flickr_cat_000778.jpg
#   inflating: cat_136/flickr_cat_000779.jpg
#   inflating: cat_136/flickr_cat_000780.jpg
#   inflating: cat_136/flickr_cat_000781.jpg
#   inflating: cat_136/flickr_cat_000782.jpg
#   inflating: cat_136/flickr_cat_000783.jpg
#   inflating: cat_136/flickr_cat_000784.jpg
#   inflating: cat_136/flickr_cat_000785.jpg
#   inflating: cat_136/flickr_cat_000786.jpg
#   inflating: cat_136/flickr_cat_000787.jpg
#   inflating: cat_136/flickr_cat_000788.jpg
#   inflating: cat_136/flickr_cat_000789.jpg
#   inflating: cat_136/flickr_cat_000790.jpg
#   inflating: cat_136/flickr_cat_000791.jpg
#   inflating: cat_136/flickr_cat_000792.jpg
#   inflating: cat_136/flickr_cat_000793.jpg
#   inflating: cat_136/flickr_cat_000794.jpg
#   inflating: cat_136/flickr_cat_000795.jpg
#   inflating: cat_136/flickr_cat_000796.jpg
#   inflating: cat_136/flickr_cat_000797.jpg
#   inflating: cat_136/flickr_cat_000798.jpg
#   inflating: cat_136/flickr_cat_000799.jpg
#   inflating: cat_136/flickr_cat_000800.jpg
#   inflating: cat_136/flickr_cat_000801.jpg
#   inflating: cat_136/flickr_cat_000803.jpg
#   inflating: cat_136/flickr_cat_000804.jpg
#   inflating: cat_136/flickr_cat_000805.jpg
#   inflating: cat_136/flickr_cat_000806.jpg
#   inflating: cat_136/flickr_cat_000807.jpg
#   inflating: cat_136/flickr_cat_000808.jpg
#   inflating: cat_136/flickr_cat_000809.jpg
#   inflating: cat_136/flickr_cat_000810.jpg
#   inflating: cat_136/flickr_cat_000811.jpg
#   inflating: cat_136/flickr_cat_000812.jpg
#   inflating: cat_136/flickr_cat_000813.jpg
#   inflating: cat_136/flickr_cat_000815.jpg
#   inflating: cat_136/flickr_cat_000817.jpg
#   inflating: cat_136/flickr_cat_000818.jpg
#   inflating: cat_136/flickr_cat_000819.jpg
#   inflating: cat_136/flickr_cat_000820.jpg
#   inflating: cat_136/flickr_cat_000821.jpg
#   inflating: cat_136/pixabay_cat_000002.jpg
#   inflating: cat_136/pixabay_cat_000003.jpg
#   inflating: cat_136/pixabay_cat_000004.jpg
#   inflating: cat_136/pixabay_cat_000005.jpg
#   inflating: cat_136/pixabay_cat_000006.jpg
#   inflating: cat_136/pixabay_cat_000008.jpg
#   inflating: cat_136/pixabay_cat_000009.jpg
#   inflating: cat_136/pixabay_cat_000011.jpg
#   inflating: cat_136/pixabay_cat_000012.jpg
#   inflating: cat_136/pixabay_cat_000013.jpg
#   inflating: cat_136/pixabay_cat_000014.jpg
#   inflating: cat_136/pixabay_cat_000015.jpg
#   inflating: cat_136/pixabay_cat_000016.jpg
#   inflating: cat_136/pixabay_cat_000017.jpg
#   inflating: cat_136/pixabay_cat_000018.jpg
#   inflating: cat_136/pixabay_cat_000019.jpg
#   inflating: cat_136/pixabay_cat_000020.jpg
#   inflating: cat_136/pixabay_cat_000021.jpg
#   inflating: cat_136/pixabay_cat_000022.jpg
#   inflating: cat_136/pixabay_cat_000023.jpg
#   inflating: cat_136/pixabay_cat_000024.jpg
#   inflating: cat_136/pixabay_cat_000025.jpg
#   inflating: cat_136/pixabay_cat_000026.jpg
#   inflating: cat_136/pixabay_cat_000027.jpg
#   inflating: cat_136/pixabay_cat_000028.jpg
#   inflating: cat_136/pixabay_cat_000029.jpg
#   inflating: cat_136/pixabay_cat_000030.jpg
#   inflating: cat_136/pixabay_cat_000031.jpg
#   inflating: cat_136/pixabay_cat_000032.jpg
#   inflating: cat_136/pixabay_cat_000033.jpg
#   inflating: cat_136/pixabay_cat_000034.jpg
#   inflating: cat_136/pixabay_cat_000035.jpg
#   inflating: cat_136/pixabay_cat_000036.jpg
#   inflating: cat_136/pixabay_cat_000038.jpg
#   inflating: cat_136/pixabay_cat_000039.jpg
#   inflating: cat_136/pixabay_cat_000041.jpg
#   inflating: cat_136/pixabay_cat_000042.jpg
#   inflating: cat_136/pixabay_cat_000043.jpg
#   inflating: cat_136/pixabay_cat_000044.jpg
#   inflating: cat_136/pixabay_cat_000045.jpg
#   inflating: cat_136/pixabay_cat_000046.jpg
#   inflating: cat_136/pixabay_cat_000047.jpg
#   inflating: cat_136/pixabay_cat_000048.jpg
#   inflating: cat_136/pixabay_cat_000049.jpg
#   inflating: cat_136/pixabay_cat_000050.jpg
#   inflating: cat_136/pixabay_cat_000052.jpg
#   inflating: cat_136/pixabay_cat_000053.jpg
#   inflating: cat_136/pixabay_cat_000054.jpg
#   inflating: cat_136/pixabay_cat_000055.jpg
#   inflating: cat_136/pixabay_cat_000056.jpg
#   inflating: cat_136/pixabay_cat_000057.jpg
#   inflating: cat_136/pixabay_cat_000058.jpg
#   inflating: cat_136/pixabay_cat_000059.jpg
#   inflating: cat_136/pixabay_cat_000060.jpg
#   inflating: cat_136/pixabay_cat_000061.jpg
#   inflating: cat_136/pixabay_cat_000062.jpg
#   inflating: cat_136/pixabay_cat_000063.jpg
#   inflating: cat_136/pixabay_cat_000064.jpg
#   inflating: cat_136/pixabay_cat_000065.jpg
#   inflating: cat_136/pixabay_cat_000066.jpg
#   inflating: cat_136/pixabay_cat_000067.jpg
#   inflating: cat_136/pixabay_cat_000068.jpg
#   inflating: cat_136/pixabay_cat_000069.jpg
#   inflating: cat_136/pixabay_cat_000071.jpg
#   inflating: cat_136/pixabay_cat_000072.jpg
#   inflating: cat_136/pixabay_cat_000073.jpg
#   inflating: cat_136/pixabay_cat_000074.jpg
#   inflating: cat_136/pixabay_cat_000075.jpg
#   inflating: cat_136/pixabay_cat_000077.jpg
#   inflating: cat_136/pixabay_cat_000078.jpg
#   inflating: cat_136/pixabay_cat_000079.jpg
#   inflating: cat_136/pixabay_cat_000080.jpg
#   inflating: cat_136/pixabay_cat_000082.jpg
#   inflating: cat_136/pixabay_cat_000083.jpg
#   inflating: cat_136/pixabay_cat_000084.jpg
#   inflating: cat_136/pixabay_cat_000085.jpg
#   inflating: cat_136/pixabay_cat_000086.jpg
#   inflating: cat_136/pixabay_cat_000087.jpg
#   inflating: cat_136/pixabay_cat_000088.jpg
#   inflating: cat_136/pixabay_cat_000089.jpg
#   inflating: cat_136/pixabay_cat_000090.jpg
#   inflating: cat_136/pixabay_cat_000091.jpg
#   inflating: cat_136/pixabay_cat_000092.jpg
#   inflating: cat_136/pixabay_cat_000093.jpg
#   inflating: cat_136/pixabay_cat_000094.jpg
#   inflating: cat_136/pixabay_cat_000095.jpg
#   inflating: cat_136/pixabay_cat_000097.jpg
#   inflating: cat_136/pixabay_cat_000098.jpg
#   inflating: cat_136/pixabay_cat_000100.jpg
#   inflating: cat_136/pixabay_cat_000101.jpg
#   inflating: cat_136/pixabay_cat_000102.jpg
#   inflating: cat_136/pixabay_cat_000103.jpg
#   inflating: cat_136/pixabay_cat_000104.jpg
#   inflating: cat_136/pixabay_cat_000105.jpg
#   inflating: cat_136/pixabay_cat_000106.jpg
#   inflating: cat_136/pixabay_cat_000107.jpg
#   inflating: cat_136/pixabay_cat_000109.jpg
#   inflating: cat_136/pixabay_cat_000110.jpg
#   inflating: cat_136/pixabay_cat_000111.jpg
#   inflating: cat_136/pixabay_cat_000112.jpg
#   inflating: cat_136/pixabay_cat_000113.jpg
#   inflating: cat_136/pixabay_cat_000114.jpg
#   inflating: cat_136/pixabay_cat_000115.jpg
#   inflating: cat_136/pixabay_cat_000116.jpg
#   inflating: cat_136/pixabay_cat_000118.jpg
#   inflating: cat_136/pixabay_cat_000119.jpg
#   inflating: cat_136/pixabay_cat_000120.jpg
#   inflating: cat_136/pixabay_cat_000121.jpg
#   inflating: cat_136/pixabay_cat_000122.jpg
#   inflating: cat_136/pixabay_cat_000123.jpg
#   inflating: cat_136/pixabay_cat_000124.jpg
#   inflating: cat_136/pixabay_cat_000125.jpg
#   inflating: cat_136/pixabay_cat_000127.jpg
#   inflating: cat_136/pixabay_cat_000128.jpg
#   inflating: cat_136/pixabay_cat_000129.jpg
#   inflating: cat_136/pixabay_cat_000130.jpg
#   inflating: cat_136/pixabay_cat_000131.jpg
#   inflating: cat_136/pixabay_cat_000132.jpg
#   inflating: cat_136/pixabay_cat_000133.jpg
#   inflating: cat_136/pixabay_cat_000134.jpg
#   inflating: cat_136/pixabay_cat_000135.jpg
#   inflating: cat_136/pixabay_cat_000136.jpg
#   inflating: cat_136/pixabay_cat_000137.jpg
#   inflating: cat_136/pixabay_cat_000138.jpg
#   inflating: cat_136/pixabay_cat_000139.jpg
#   inflating: cat_136/pixabay_cat_000140.jpg
#   inflating: cat_136/pixabay_cat_000141.jpg
#   inflating: cat_136/pixabay_cat_000142.jpg
#   inflating: cat_136/pixabay_cat_000143.jpg
#   inflating: cat_136/pixabay_cat_000144.jpg
#   inflating: cat_136/pixabay_cat_000145.jpg
#   inflating: cat_136/pixabay_cat_000146.jpg
#   inflating: cat_136/pixabay_cat_000148.jpg
#   inflating: cat_136/pixabay_cat_000149.jpg
#   inflating: cat_136/pixabay_cat_000150.jpg
#   inflating: cat_136/pixabay_cat_000152.jpg
#   inflating: cat_136/pixabay_cat_000153.jpg
#   inflating: cat_136/pixabay_cat_000154.jpg
#   inflating: cat_136/pixabay_cat_000155.jpg
#   inflating: cat_136/pixabay_cat_000156.jpg
#   inflating: cat_136/pixabay_cat_000157.jpg
#   inflating: cat_136/pixabay_cat_000158.jpg
#   inflating: cat_136/pixabay_cat_000159.jpg
#   inflating: cat_136/pixabay_cat_000160.jpg
#   inflating: cat_136/pixabay_cat_000161.jpg
#   inflating: cat_136/pixabay_cat_000162.jpg
#   inflating: cat_136/pixabay_cat_000163.jpg
#   inflating: cat_136/pixabay_cat_000164.jpg
#   inflating: cat_136/pixabay_cat_000166.jpg
#   inflating: cat_136/pixabay_cat_000167.jpg
#   inflating: cat_136/pixabay_cat_000168.jpg
#   inflating: cat_136/pixabay_cat_000170.jpg
#   inflating: cat_136/pixabay_cat_000171.jpg
#   inflating: cat_136/pixabay_cat_000172.jpg
#   inflating: cat_136/pixabay_cat_000173.jpg
#   inflating: cat_136/pixabay_cat_000174.jpg
#   inflating: cat_136/pixabay_cat_000175.jpg
#   inflating: cat_136/pixabay_cat_000176.jpg
#   inflating: cat_136/pixabay_cat_000177.jpg
#   inflating: cat_136/pixabay_cat_000179.jpg
#   inflating: cat_136/pixabay_cat_000180.jpg
#   inflating: cat_136/pixabay_cat_000182.jpg
#   inflating: cat_136/pixabay_cat_000183.jpg
#   inflating: cat_136/pixabay_cat_000184.jpg
#   inflating: cat_136/pixabay_cat_000185.jpg
#   inflating: cat_136/pixabay_cat_000186.jpg
#   inflating: cat_136/pixabay_cat_000187.jpg
#   inflating: cat_136/pixabay_cat_000188.jpg
#   inflating: cat_136/pixabay_cat_000189.jpg
#   inflating: cat_136/pixabay_cat_000191.jpg
#   inflating: cat_136/pixabay_cat_000192.jpg
#   inflating: cat_136/pixabay_cat_000193.jpg
#   inflating: cat_136/pixabay_cat_000194.jpg
#   inflating: cat_136/pixabay_cat_000195.jpg
#   inflating: cat_136/pixabay_cat_000196.jpg
#   inflating: cat_136/pixabay_cat_000197.jpg
#   inflating: cat_136/pixabay_cat_000198.jpg
#   inflating: cat_136/pixabay_cat_000199.jpg
#   inflating: cat_136/pixabay_cat_000200.jpg
#   inflating: cat_136/pixabay_cat_000201.jpg
#   inflating: cat_136/pixabay_cat_000203.jpg
#   inflating: cat_136/pixabay_cat_000204.jpg
#   inflating: cat_136/pixabay_cat_000205.jpg
#   inflating: cat_136/pixabay_cat_000206.jpg
#   inflating: cat_136/pixabay_cat_000207.jpg
#   inflating: cat_136/pixabay_cat_000208.jpg
#   inflating: cat_136/pixabay_cat_000209.jpg
#   inflating: cat_136/pixabay_cat_000210.jpg
#   inflating: cat_136/pixabay_cat_000211.jpg
#   inflating: cat_136/pixabay_cat_000212.jpg
#   inflating: cat_136/pixabay_cat_000213.jpg
#   inflating: cat_136/pixabay_cat_000214.jpg
#   inflating: cat_136/pixabay_cat_000215.jpg
#   inflating: cat_136/pixabay_cat_000216.jpg
#   inflating: cat_136/pixabay_cat_000217.jpg
#   inflating: cat_136/pixabay_cat_000218.jpg
#   inflating: cat_136/pixabay_cat_000219.jpg
#   inflating: cat_136/pixabay_cat_000220.jpg
#   inflating: cat_136/pixabay_cat_000221.jpg
#   inflating: cat_136/pixabay_cat_000222.jpg
#   inflating: cat_136/pixabay_cat_000223.jpg
#   inflating: cat_136/pixabay_cat_000224.jpg
#   inflating: cat_136/pixabay_cat_000225.jpg
#   inflating: cat_136/pixabay_cat_000226.jpg
#   inflating: cat_136/pixabay_cat_000227.jpg
#   inflating: cat_136/pixabay_cat_000228.jpg
#   inflating: cat_136/pixabay_cat_000229.jpg
#   inflating: cat_136/pixabay_cat_000230.jpg
#   inflating: cat_136/pixabay_cat_000232.jpg
#   inflating: cat_136/pixabay_cat_000233.jpg
#   inflating: cat_136/pixabay_cat_000234.jpg
#   inflating: cat_136/pixabay_cat_000235.jpg
#   inflating: cat_136/pixabay_cat_000236.jpg
#   inflating: cat_136/pixabay_cat_000237.jpg
#   inflating: cat_136/pixabay_cat_000238.jpg
#   inflating: cat_136/pixabay_cat_000239.jpg
#   inflating: cat_136/pixabay_cat_000240.jpg
#   inflating: cat_136/pixabay_cat_000242.jpg
#   inflating: cat_136/pixabay_cat_000243.jpg
#   inflating: cat_136/pixabay_cat_000244.jpg
#   inflating: cat_136/pixabay_cat_000245.jpg
#   inflating: cat_136/pixabay_cat_000246.jpg
#   inflating: cat_136/pixabay_cat_000247.jpg
#   inflating: cat_136/pixabay_cat_000249.jpg
#   inflating: cat_136/pixabay_cat_000250.jpg
#   inflating: cat_136/pixabay_cat_000251.jpg
#   inflating: cat_136/pixabay_cat_000252.jpg
#   inflating: cat_136/pixabay_cat_000253.jpg
#   inflating: cat_136/pixabay_cat_000254.jpg
#   inflating: cat_136/pixabay_cat_000255.jpg
#   inflating: cat_136/pixabay_cat_000256.jpg
#   inflating: cat_136/pixabay_cat_000257.jpg
#   inflating: cat_136/pixabay_cat_000258.jpg
#   inflating: cat_136/pixabay_cat_000259.jpg
#   inflating: cat_136/pixabay_cat_000260.jpg
#   inflating: cat_136/pixabay_cat_000261.jpg
#   inflating: cat_136/pixabay_cat_000262.jpg
#   inflating: cat_136/pixabay_cat_000263.jpg
#   inflating: cat_136/pixabay_cat_000264.jpg
#   inflating: cat_136/pixabay_cat_000265.jpg
#   inflating: cat_136/pixabay_cat_000266.jpg
#   inflating: cat_136/pixabay_cat_000267.jpg
#   inflating: cat_136/pixabay_cat_000268.jpg
#   inflating: cat_136/pixabay_cat_000269.jpg
#   inflating: cat_136/pixabay_cat_000270.jpg
#   inflating: cat_136/pixabay_cat_000271.jpg
#   inflating: cat_136/pixabay_cat_000272.jpg
#   inflating: cat_136/pixabay_cat_000273.jpg
#   inflating: cat_136/pixabay_cat_000274.jpg
#   inflating: cat_136/pixabay_cat_000275.jpg
#   inflating: cat_136/pixabay_cat_000277.jpg
#   inflating: cat_136/pixabay_cat_000278.jpg
#   inflating: cat_136/pixabay_cat_000279.jpg
#   inflating: cat_136/pixabay_cat_000280.jpg
#   inflating: cat_136/pixabay_cat_000281.jpg
#   inflating: cat_136/pixabay_cat_000282.jpg
#   inflating: cat_136/pixabay_cat_000283.jpg
#   inflating: cat_136/pixabay_cat_000284.jpg
#   inflating: cat_136/pixabay_cat_000285.jpg
#   inflating: cat_136/pixabay_cat_000286.jpg
#   inflating: cat_136/pixabay_cat_000287.jpg
#   inflating: cat_136/pixabay_cat_000288.jpg
#   inflating: cat_136/pixabay_cat_000289.jpg
#   inflating: cat_136/pixabay_cat_000290.jpg
#   inflating: cat_136/pixabay_cat_000292.jpg
#   inflating: cat_136/pixabay_cat_000293.jpg
#   inflating: cat_136/pixabay_cat_000294.jpg
#   inflating: cat_136/pixabay_cat_000295.jpg
#   inflating: cat_136/pixabay_cat_000297.jpg
#   inflating: cat_136/pixabay_cat_000298.jpg
#   inflating: cat_136/pixabay_cat_000300.jpg
#   inflating: cat_136/pixabay_cat_000301.jpg
#   inflating: cat_136/pixabay_cat_000303.jpg
#   inflating: cat_136/pixabay_cat_000304.jpg
#   inflating: cat_136/pixabay_cat_000305.jpg
#   inflating: cat_136/pixabay_cat_000306.jpg
#   inflating: cat_136/pixabay_cat_000307.jpg
#   inflating: cat_136/pixabay_cat_000308.jpg
#   inflating: cat_136/pixabay_cat_000309.jpg
#   inflating: cat_136/pixabay_cat_000310.jpg
#   inflating: cat_136/pixabay_cat_000311.jpg
#   inflating: cat_136/pixabay_cat_000312.jpg
#   inflating: cat_136/pixabay_cat_000313.jpg
#   inflating: cat_136/pixabay_cat_000316.jpg
#   inflating: cat_136/pixabay_cat_000317.jpg
#   inflating: cat_136/pixabay_cat_000318.jpg
#   inflating: cat_136/pixabay_cat_000319.jpg
#   inflating: cat_136/pixabay_cat_000320.jpg
#   inflating: cat_136/pixabay_cat_000321.jpg
#   inflating: cat_136/pixabay_cat_000322.jpg
#   inflating: cat_136/pixabay_cat_000323.jpg
#   inflating: cat_136/pixabay_cat_000324.jpg
#   inflating: cat_136/pixabay_cat_000326.jpg
#   inflating: cat_136/pixabay_cat_000327.jpg
#   inflating: cat_136/pixabay_cat_000328.jpg
#   inflating: cat_136/pixabay_cat_000329.jpg
#   inflating: cat_136/pixabay_cat_000330.jpg
#   inflating: cat_136/pixabay_cat_000331.jpg
#   inflating: cat_136/pixabay_cat_000332.jpg
#   inflating: cat_136/pixabay_cat_000333.jpg
#   inflating: cat_136/pixabay_cat_000334.jpg
#   inflating: cat_136/pixabay_cat_000335.jpg
#   inflating: cat_136/pixabay_cat_000336.jpg
#   inflating: cat_136/pixabay_cat_000337.jpg
#   inflating: cat_136/pixabay_cat_000338.jpg
#   inflating: cat_136/pixabay_cat_000340.jpg
#   inflating: cat_136/pixabay_cat_000341.jpg
#   inflating: cat_136/pixabay_cat_000342.jpg
#   inflating: cat_136/pixabay_cat_000344.jpg
#   inflating: cat_136/pixabay_cat_000345.jpg
#   inflating: cat_136/pixabay_cat_000346.jpg
#   inflating: cat_136/pixabay_cat_000347.jpg
#   inflating: cat_136/pixabay_cat_000348.jpg
#   inflating: cat_136/pixabay_cat_000349.jpg
#   inflating: cat_136/pixabay_cat_000350.jpg
#   inflating: cat_136/pixabay_cat_000351.jpg
#   inflating: cat_136/pixabay_cat_000352.jpg
#   inflating: cat_136/pixabay_cat_000354.jpg
#   inflating: cat_136/pixabay_cat_000356.jpg
#   inflating: cat_136/pixabay_cat_000357.jpg
#   inflating: cat_136/pixabay_cat_000358.jpg
#   inflating: cat_136/pixabay_cat_000359.jpg
#   inflating: cat_136/pixabay_cat_000360.jpg
#   inflating: cat_136/pixabay_cat_000361.jpg
#   inflating: cat_136/pixabay_cat_000362.jpg
#   inflating: cat_136/pixabay_cat_000363.jpg
#   inflating: cat_136/pixabay_cat_000364.jpg
#   inflating: cat_136/pixabay_cat_000365.jpg
#   inflating: cat_136/pixabay_cat_000366.jpg
#   inflating: cat_136/pixabay_cat_000367.jpg
#   inflating: cat_136/pixabay_cat_000368.jpg
#   inflating: cat_136/pixabay_cat_000369.jpg
#   inflating: cat_136/pixabay_cat_000370.jpg
#   inflating: cat_136/pixabay_cat_000371.jpg
#   inflating: cat_136/pixabay_cat_000372.jpg
#   inflating: cat_136/pixabay_cat_000373.jpg
#   inflating: cat_136/pixabay_cat_000374.jpg
#   inflating: cat_136/pixabay_cat_000375.jpg
#   inflating: cat_136/pixabay_cat_000376.jpg
#   inflating: cat_136/pixabay_cat_000377.jpg
#   inflating: cat_136/pixabay_cat_000378.jpg
#   inflating: cat_136/pixabay_cat_000379.jpg
#   inflating: cat_136/pixabay_cat_000381.jpg
#   inflating: cat_136/pixabay_cat_000382.jpg
#   inflating: cat_136/pixabay_cat_000383.jpg
#   inflating: cat_136/pixabay_cat_000384.jpg
#   inflating: cat_136/pixabay_cat_000385.jpg
#   inflating: cat_136/pixabay_cat_000386.jpg
#   inflating: cat_136/pixabay_cat_000387.jpg
#   inflating: cat_136/pixabay_cat_000388.jpg
#   inflating: cat_136/pixabay_cat_000389.jpg
#   inflating: cat_136/pixabay_cat_000391.jpg
#   inflating: cat_136/pixabay_cat_000393.jpg
#   inflating: cat_136/pixabay_cat_000394.jpg
#   inflating: cat_136/pixabay_cat_000395.jpg
#   inflating: cat_136/pixabay_cat_000396.jpg
#   inflating: cat_136/pixabay_cat_000397.jpg
#   inflating: cat_136/pixabay_cat_000398.jpg
#   inflating: cat_136/pixabay_cat_000399.jpg
#   inflating: cat_136/pixabay_cat_000400.jpg
#   inflating: cat_136/pixabay_cat_000401.jpg
#   inflating: cat_136/pixabay_cat_000402.jpg
#   inflating: cat_136/pixabay_cat_000404.jpg
#   inflating: cat_136/pixabay_cat_000405.jpg
#   inflating: cat_136/pixabay_cat_000406.jpg
#   inflating: cat_136/pixabay_cat_000407.jpg
#   inflating: cat_136/pixabay_cat_000408.jpg
#   inflating: cat_136/pixabay_cat_000409.jpg
#   inflating: cat_136/pixabay_cat_000410.jpg
#   inflating: cat_136/pixabay_cat_000411.jpg
#   inflating: cat_136/pixabay_cat_000412.jpg
#   inflating: cat_136/pixabay_cat_000413.jpg
#   inflating: cat_136/pixabay_cat_000414.jpg
#   inflating: cat_136/pixabay_cat_000415.jpg
#   inflating: cat_136/pixabay_cat_000416.jpg
#   inflating: cat_136/pixabay_cat_000418.jpg
#   inflating: cat_136/pixabay_cat_000419.jpg
#   inflating: cat_136/pixabay_cat_000420.jpg
#   inflating: cat_136/pixabay_cat_000421.jpg
#   inflating: cat_136/pixabay_cat_000422.jpg
#   inflating: cat_136/pixabay_cat_000423.jpg
#   inflating: cat_136/pixabay_cat_000424.jpg
#   inflating: cat_136/pixabay_cat_000425.jpg
#   inflating: cat_136/pixabay_cat_000426.jpg
#   inflating: cat_136/pixabay_cat_000427.jpg
#   inflating: cat_136/pixabay_cat_000428.jpg
#   inflating: cat_136/pixabay_cat_000429.jpg
#   inflating: cat_136/pixabay_cat_000430.jpg
#   inflating: cat_136/pixabay_cat_000431.jpg
#   inflating: cat_136/pixabay_cat_000432.jpg
#   inflating: cat_136/pixabay_cat_000433.jpg
#   inflating: cat_136/pixabay_cat_000434.jpg
#   inflating: cat_136/pixabay_cat_000435.jpg
#   inflating: cat_136/pixabay_cat_000436.jpg
#   inflating: cat_136/pixabay_cat_000437.jpg
#   inflating: cat_136/pixabay_cat_000438.jpg
#   inflating: cat_136/pixabay_cat_000439.jpg
#   inflating: cat_136/pixabay_cat_000442.jpg
#   inflating: cat_136/pixabay_cat_000443.jpg
#   inflating: cat_136/pixabay_cat_000444.jpg
#   inflating: cat_136/pixabay_cat_000445.jpg
#   inflating: cat_136/pixabay_cat_000446.jpg
#   inflating: cat_136/pixabay_cat_000447.jpg
#   inflating: cat_136/pixabay_cat_000448.jpg
#   inflating: cat_136/pixabay_cat_000449.jpg
#   inflating: cat_136/pixabay_cat_000450.jpg
#   inflating: cat_136/pixabay_cat_000451.jpg
#   inflating: cat_136/pixabay_cat_000452.jpg
#   inflating: cat_136/pixabay_cat_000453.jpg
#   inflating: cat_136/pixabay_cat_000454.jpg
#   inflating: cat_136/pixabay_cat_000455.jpg
#   inflating: cat_136/pixabay_cat_000456.jpg
#   inflating: cat_136/pixabay_cat_000457.jpg
#   inflating: cat_136/pixabay_cat_000458.jpg
#   inflating: cat_136/pixabay_cat_000460.jpg
#   inflating: cat_136/pixabay_cat_000461.jpg
#   inflating: cat_136/pixabay_cat_000462.jpg
#   inflating: cat_136/pixabay_cat_000463.jpg
#   inflating: cat_136/pixabay_cat_000464.jpg
#   inflating: cat_136/pixabay_cat_000465.jpg
#   inflating: cat_136/pixabay_cat_000466.jpg
#   inflating: cat_136/pixabay_cat_000467.jpg
#   inflating: cat_136/pixabay_cat_000469.jpg
#   inflating: cat_136/pixabay_cat_000470.jpg
#   inflating: cat_136/pixabay_cat_000471.jpg
#   inflating: cat_136/pixabay_cat_000472.jpg
#   inflating: cat_136/pixabay_cat_000473.jpg
#   inflating: cat_136/pixabay_cat_000474.jpg
#   inflating: cat_136/pixabay_cat_000475.jpg
#   inflating: cat_136/pixabay_cat_000476.jpg
#   inflating: cat_136/pixabay_cat_000477.jpg
#   inflating: cat_136/pixabay_cat_000478.jpg
#   inflating: cat_136/pixabay_cat_000479.jpg
#   inflating: cat_136/pixabay_cat_000480.jpg
#   inflating: cat_136/pixabay_cat_000481.jpg
#   inflating: cat_136/pixabay_cat_000482.jpg
#   inflating: cat_136/pixabay_cat_000483.jpg
#   inflating: cat_136/pixabay_cat_000484.jpg
#   inflating: cat_136/pixabay_cat_000485.jpg
#   inflating: cat_136/pixabay_cat_000486.jpg
#   inflating: cat_136/pixabay_cat_000487.jpg
#   inflating: cat_136/pixabay_cat_000488.jpg
#   inflating: cat_136/pixabay_cat_000489.jpg
#   inflating: cat_136/pixabay_cat_000490.jpg
#   inflating: cat_136/pixabay_cat_000493.jpg
#   inflating: cat_136/pixabay_cat_000494.jpg
#   inflating: cat_136/pixabay_cat_000495.jpg
#   inflating: cat_136/pixabay_cat_000496.jpg
#   inflating: cat_136/pixabay_cat_000497.jpg
#   inflating: cat_136/pixabay_cat_000498.jpg
#   inflating: cat_136/pixabay_cat_000499.jpg
#   inflating: cat_136/pixabay_cat_000500.jpg
#   inflating: cat_136/pixabay_cat_000501.jpg
#   inflating: cat_136/pixabay_cat_000502.jpg
#   inflating: cat_136/pixabay_cat_000503.jpg
#   inflating: cat_136/pixabay_cat_000505.jpg
#   inflating: cat_136/pixabay_cat_000506.jpg
#   inflating: cat_136/pixabay_cat_000507.jpg
#   inflating: cat_136/pixabay_cat_000508.jpg
#   inflating: cat_136/pixabay_cat_000509.jpg
#   inflating: cat_136/pixabay_cat_000510.jpg
#   inflating: cat_136/pixabay_cat_000511.jpg
#   inflating: cat_136/pixabay_cat_000512.jpg
#   inflating: cat_136/pixabay_cat_000513.jpg
#   inflating: cat_136/pixabay_cat_000515.jpg
#   inflating: cat_136/pixabay_cat_000516.jpg
#   inflating: cat_136/pixabay_cat_000517.jpg
#   inflating: cat_136/pixabay_cat_000519.jpg
#   inflating: cat_136/pixabay_cat_000520.jpg
#   inflating: cat_136/pixabay_cat_000521.jpg
#   inflating: cat_136/pixabay_cat_000522.jpg
#   inflating: cat_136/pixabay_cat_000523.jpg
#   inflating: cat_136/pixabay_cat_000524.jpg
#   inflating: cat_136/pixabay_cat_000525.jpg
#   inflating: cat_136/pixabay_cat_000526.jpg
#   inflating: cat_136/pixabay_cat_000527.jpg
# ...
#   inflating: cat_136/pixabay_cat_004449.jpg
#   inflating: cat_136/pixabay_cat_004450.jpg
#   inflating: cat_136/pixabay_cat_004451.jpg
#   inflating: cat_136/pixabay_cat_004452.jpg
#   inflating: cat_136/pixabay_cat_004453.jpg
#   inflating: cat_136/pixabay_cat_004454.jpg
#   inflating: cat_136/pixabay_cat_004455.jpg
#   inflating: cat_136/pixabay_cat_004456.jpg
#   inflating: cat_136/pixabay_cat_004457.jpg
#   inflating: cat_136/pixabay_cat_004458.jpg
#   inflating: cat_136/pixabay_cat_004459.jpg
#   inflating: cat_136/pixabay_cat_004460.jpg
#   inflating: cat_136/pixabay_cat_004462.jpg
#   inflating: cat_136/pixabay_cat_004463.jpg
#   inflating: cat_136/pixabay_cat_004464.jpg
#   inflating: cat_136/pixabay_cat_004465.jpg
#   inflating: cat_136/pixabay_cat_004466.jpg
#   inflating: cat_136/pixabay_cat_004467.jpg
#   inflating: cat_136/pixabay_cat_004468.jpg
#   inflating: cat_136/pixabay_cat_004469.jpg
#   inflating: cat_136/pixabay_cat_004470.jpg
#   inflating: cat_136/pixabay_cat_004471.jpg
#   inflating: cat_136/pixabay_cat_004472.jpg
#   inflating: cat_136/pixabay_cat_004473.jpg
#   inflating: cat_136/pixabay_cat_004474.jpg
#   inflating: cat_136/pixabay_cat_004475.jpg
#   inflating: cat_136/pixabay_cat_004476.jpg
#   inflating: cat_136/pixabay_cat_004477.jpg
#   inflating: cat_136/pixabay_cat_004478.jpg
#   inflating: cat_136/pixabay_cat_004479.jpg
#   inflating: cat_136/pixabay_cat_004481.jpg
#   inflating: cat_136/pixabay_cat_004483.jpg
#   inflating: cat_136/pixabay_cat_004485.jpg
#   inflating: cat_136/pixabay_cat_004486.jpg
#   inflating: cat_136/pixabay_cat_004487.jpg
#   inflating: cat_136/pixabay_cat_004488.jpg
#   inflating: cat_136/pixabay_cat_004489.jpg
#   inflating: cat_136/pixabay_cat_004490.jpg
#   inflating: cat_136/pixabay_cat_004491.jpg
#   inflating: cat_136/pixabay_cat_004492.jpg
#   inflating: cat_136/pixabay_cat_004493.jpg
#   inflating: cat_136/pixabay_cat_004494.jpg
#   inflating: cat_136/pixabay_cat_004495.jpg
#   inflating: cat_136/pixabay_cat_004496.jpg
#   inflating: cat_136/pixabay_cat_004497.jpg
#   inflating: cat_136/pixabay_cat_004498.jpg
#   inflating: cat_136/pixabay_cat_004499.jpg
#   inflating: cat_136/pixabay_cat_004500.jpg
#   inflating: cat_136/pixabay_cat_004501.jpg
#   inflating: cat_136/pixabay_cat_004502.jpg
#   inflating: cat_136/pixabay_cat_004503.jpg
#   inflating: cat_136/pixabay_cat_004504.jpg
#   inflating: cat_136/pixabay_cat_004506.jpg
#   inflating: cat_136/pixabay_cat_004507.jpg
#   inflating: cat_136/pixabay_cat_004508.jpg
#   inflating: cat_136/pixabay_cat_004509.jpg
#   inflating: cat_136/pixabay_cat_004511.jpg
#   inflating: cat_136/pixabay_cat_004512.jpg
#   inflating: cat_136/pixabay_cat_004514.jpg
#   inflating: cat_136/pixabay_cat_004515.jpg
#   inflating: cat_136/pixabay_cat_004516.jpg
#   inflating: cat_136/pixabay_cat_004517.jpg
#   inflating: cat_136/pixabay_cat_004518.jpg
#   inflating: cat_136/pixabay_cat_004519.jpg
#   inflating: cat_136/pixabay_cat_004521.jpg
#   inflating: cat_136/pixabay_cat_004522.jpg
#   inflating: cat_136/pixabay_cat_004523.jpg
#   inflating: cat_136/pixabay_cat_004524.jpg
#   inflating: cat_136/pixabay_cat_004525.jpg
#   inflating: cat_136/pixabay_cat_004526.jpg
#   inflating: cat_136/pixabay_cat_004527.jpg
#   inflating: cat_136/pixabay_cat_004528.jpg
#   inflating: cat_136/pixabay_cat_004529.jpg
#   inflating: cat_136/pixabay_cat_004530.jpg
#   inflating: cat_136/pixabay_cat_004531.jpg
#   inflating: cat_136/pixabay_cat_004532.jpg
#   inflating: cat_136/pixabay_cat_004533.jpg
#   inflating: cat_136/pixabay_cat_004534.jpg
#   inflating: cat_136/pixabay_cat_004535.jpg
#   inflating: cat_136/pixabay_cat_004536.jpg
#   inflating: cat_136/pixabay_cat_004537.jpg
#   inflating: cat_136/pixabay_cat_004538.jpg
#   inflating: cat_136/pixabay_cat_004539.jpg
#   inflating: cat_136/pixabay_cat_004540.jpg
#   inflating: cat_136/pixabay_cat_004541.jpg
#   inflating: cat_136/pixabay_cat_004544.jpg
#   inflating: cat_136/pixabay_cat_004545.jpg
#   inflating: cat_136/pixabay_cat_004546.jpg
#   inflating: cat_136/pixabay_cat_004547.jpg
#   inflating: cat_136/pixabay_cat_004549.jpg
#   inflating: cat_136/pixabay_cat_004550.jpg
#   inflating: cat_136/pixabay_cat_004551.jpg
#   inflating: cat_136/pixabay_cat_004552.jpg
#   inflating: cat_136/pixabay_cat_004553.jpg
#   inflating: cat_136/pixabay_cat_004554.jpg
#   inflating: cat_136/pixabay_cat_004555.jpg
#   inflating: cat_136/pixabay_cat_004556.jpg
#   inflating: cat_136/pixabay_cat_004557.jpg
#   inflating: cat_136/pixabay_cat_004558.jpg
#   inflating: cat_136/pixabay_cat_004559.jpg
#   inflating: cat_136/pixabay_cat_004560.jpg
#   inflating: cat_136/pixabay_cat_004561.jpg
#   inflating: cat_136/pixabay_cat_004563.jpg
#   inflating: cat_136/pixabay_cat_004564.jpg
#   inflating: cat_136/pixabay_cat_004565.jpg
#   inflating: cat_136/pixabay_cat_004566.jpg
#   inflating: cat_136/pixabay_cat_004567.jpg
#   inflating: cat_136/pixabay_cat_004568.jpg
#   inflating: cat_136/pixabay_cat_004569.jpg
#   inflating: cat_136/pixabay_cat_004570.jpg
#   inflating: cat_136/pixabay_cat_004571.jpg
#   inflating: cat_136/pixabay_cat_004572.jpg
#   inflating: cat_136/pixabay_cat_004573.jpg
#   inflating: cat_136/pixabay_cat_004574.jpg
#   inflating: cat_136/pixabay_cat_004575.jpg
#   inflating: cat_136/pixabay_cat_004576.jpg
#   inflating: cat_136/pixabay_cat_004577.jpg
#   inflating: cat_136/pixabay_cat_004578.jpg
#   inflating: cat_136/pixabay_cat_004579.jpg
#   inflating: cat_136/pixabay_cat_004580.jpg
#   inflating: cat_136/pixabay_cat_004581.jpg
#   inflating: cat_136/pixabay_cat_004582.jpg
#   inflating: cat_136/pixabay_cat_004583.jpg
#   inflating: cat_136/pixabay_cat_004585.jpg
#   inflating: cat_136/pixabay_cat_004587.jpg
#   inflating: cat_136/pixabay_cat_004588.jpg
#   inflating: cat_136/pixabay_cat_004589.jpg
#   inflating: cat_136/pixabay_cat_004590.jpg
#   inflating: cat_136/pixabay_cat_004591.jpg
#   inflating: cat_136/pixabay_cat_004592.jpg
#   inflating: cat_136/pixabay_cat_004593.jpg
#   inflating: cat_136/pixabay_cat_004594.jpg
#   inflating: cat_136/pixabay_cat_004597.jpg
#   inflating: cat_136/pixabay_cat_004598.jpg
#   inflating: cat_136/pixabay_cat_004599.jpg
#   inflating: cat_136/pixabay_cat_004600.jpg
#   inflating: cat_136/pixabay_cat_004603.jpg
#   inflating: cat_136/pixabay_cat_004604.jpg
#   inflating: cat_136/pixabay_cat_004605.jpg
#   inflating: cat_136/pixabay_cat_004606.jpg
#   inflating: cat_136/pixabay_cat_004607.jpg
#   inflating: cat_136/pixabay_cat_004608.jpg
#   inflating: cat_136/pixabay_cat_004609.jpg
#   inflating: cat_136/pixabay_cat_004610.jpg
#   inflating: cat_136/pixabay_cat_004611.jpg
#   inflating: cat_136/pixabay_cat_004612.jpg
#   inflating: cat_136/pixabay_cat_004613.jpg
#   inflating: cat_136/pixabay_cat_004614.jpg
#   inflating: cat_136/pixabay_cat_004615.jpg
#   inflating: cat_136/pixabay_cat_004617.jpg
#   inflating: cat_136/pixabay_cat_004618.jpg
#   inflating: cat_136/pixabay_cat_004619.jpg
#   inflating: cat_136/pixabay_cat_004620.jpg
#   inflating: cat_136/pixabay_cat_004621.jpg
#   inflating: cat_136/pixabay_cat_004622.jpg
#   inflating: cat_136/pixabay_cat_004623.jpg
#   inflating: cat_136/pixabay_cat_004624.jpg
#   inflating: cat_136/pixabay_cat_004626.jpg
#   inflating: cat_136/pixabay_cat_004627.jpg
#   inflating: cat_136/pixabay_cat_004628.jpg
#   inflating: cat_136/pixabay_cat_004629.jpg
#   inflating: cat_136/pixabay_cat_004630.jpg
#   inflating: cat_136/pixabay_cat_004631.jpg
#   inflating: cat_136/pixabay_cat_004632.jpg
#   inflating: cat_136/pixabay_cat_004633.jpg
#   inflating: cat_136/pixabay_cat_004634.jpg
#   inflating: cat_136/pixabay_cat_004637.jpg
#   inflating: cat_136/pixabay_cat_004638.jpg
#   inflating: cat_136/pixabay_cat_004639.jpg
#   inflating: cat_136/pixabay_cat_004640.jpg
#   inflating: cat_136/pixabay_cat_004641.jpg
#   inflating: cat_136/pixabay_cat_004642.jpg
#   inflating: cat_136/pixabay_cat_004643.jpg
#   inflating: cat_136/pixabay_cat_004644.jpg
#   inflating: cat_136/pixabay_cat_004645.jpg
#   inflating: cat_136/pixabay_cat_004646.jpg
#   inflating: cat_136/pixabay_cat_004647.jpg
#   inflating: cat_136/pixabay_cat_004648.jpg
#   inflating: cat_136/pixabay_cat_004649.jpg
#   inflating: cat_136/pixabay_cat_004650.jpg
#   inflating: cat_136/pixabay_cat_004651.jpg
#   inflating: cat_136/pixabay_cat_004653.jpg
#   inflating: cat_136/pixabay_cat_004654.jpg
#   inflating: cat_136/pixabay_cat_004656.jpg
#   inflating: cat_136/pixabay_cat_004657.jpg
#   inflating: cat_136/pixabay_cat_004658.jpg
#   inflating: cat_136/pixabay_cat_004659.jpg
#   inflating: cat_136/pixabay_cat_004660.jpg
#   inflating: cat_136/pixabay_cat_004661.jpg
#   inflating: cat_136/pixabay_cat_004664.jpg
#   inflating: cat_136/pixabay_cat_004665.jpg
#   inflating: cat_136/pixabay_cat_004666.jpg
#   inflating: cat_136/pixabay_cat_004667.jpg
#   inflating: cat_136/pixabay_cat_004668.jpg
#   inflating: cat_136/pixabay_cat_004669.jpg
#   inflating: cat_136/pixabay_cat_004670.jpg
#   inflating: cat_136/pixabay_cat_004671.jpg
#   inflating: cat_136/pixabay_cat_004672.jpg
#   inflating: cat_136/pixabay_cat_004673.jpg
#   inflating: cat_136/pixabay_cat_004674.jpg
#   inflating: cat_136/pixabay_cat_004675.jpg
#   inflating: cat_136/pixabay_cat_004676.jpg
#   inflating: cat_136/pixabay_cat_004677.jpg
#   inflating: cat_136/pixabay_cat_004678.jpg
#   inflating: cat_136/pixabay_cat_004679.jpg
#   inflating: cat_136/pixabay_cat_004680.jpg
#   inflating: cat_136/pixabay_cat_004681.jpg
#   inflating: cat_136/pixabay_cat_004682.jpg
#   inflating: cat_136/pixabay_cat_004683.jpg
#   inflating: cat_136/pixabay_cat_004684.jpg
#   inflating: cat_136/pixabay_cat_004686.jpg
#   inflating: cat_136/pixabay_cat_004687.jpg
#   inflating: cat_136/pixabay_cat_004688.jpg
#   inflating: cat_136/pixabay_cat_004689.jpg
#   inflating: cat_136/pixabay_cat_004690.jpg
#   inflating: cat_136/pixabay_cat_004691.jpg
#   inflating: cat_136/pixabay_cat_004692.jpg
#   inflating: cat_136/pixabay_cat_004694.jpg
#   inflating: cat_136/pixabay_cat_004695.jpg
#   inflating: cat_136/pixabay_cat_004696.jpg
#   inflating: cat_136/pixabay_cat_004697.jpg
#   inflating: cat_136/pixabay_cat_004698.jpg
#   inflating: cat_136/pixabay_cat_004699.jpg
#   inflating: cat_136/pixabay_cat_004700.jpg
#   inflating: cat_136/pixabay_cat_004701.jpg
#   inflating: cat_136/pixabay_cat_004702.jpg
#   inflating: cat_136/pixabay_cat_004703.jpg
#   inflating: cat_136/pixabay_cat_004704.jpg
#   inflating: cat_136/pixabay_cat_004705.jpg
#   inflating: cat_136/pixabay_cat_004706.jpg
#   inflating: cat_136/pixabay_cat_004707.jpg
#   inflating: cat_136/pixabay_cat_004708.jpg
#   inflating: cat_136/pixabay_cat_004709.jpg
#   inflating: cat_136/pixabay_cat_004710.jpg
#   inflating: cat_136/pixabay_cat_004711.jpg
#   inflating: cat_136/pixabay_cat_004712.jpg
#   inflating: cat_136/pixabay_cat_004713.jpg
#   inflating: cat_136/pixabay_cat_004714.jpg
#   inflating: cat_136/pixabay_cat_004715.jpg
#   inflating: cat_136/pixabay_cat_004716.jpg
#   inflating: cat_136/pixabay_cat_004717.jpg
#   inflating: cat_136/pixabay_cat_004718.jpg
#   inflating: cat_136/pixabay_cat_004719.jpg
#   inflating: cat_136/pixabay_cat_004720.jpg
#   inflating: cat_136/pixabay_cat_004721.jpg
#   inflating: cat_136/pixabay_cat_004722.jpg
#   inflating: cat_136/pixabay_cat_004723.jpg
#   inflating: cat_136/pixabay_cat_004724.jpg
#   inflating: cat_136/pixabay_cat_004725.jpg
#   inflating: cat_136/pixabay_cat_004726.jpg
#   inflating: cat_136/pixabay_cat_004727.jpg
#   inflating: cat_136/pixabay_cat_004728.jpg
#   inflating: cat_136/pixabay_cat_004729.jpg
#   inflating: cat_136/pixabay_cat_004730.jpg
#   inflating: cat_136/pixabay_cat_004731.jpg
#   inflating: cat_136/pixabay_cat_004732.jpg
#   inflating: cat_136/pixabay_cat_004733.jpg
#   inflating: cat_136/pixabay_cat_004734.jpg
#   inflating: cat_136/pixabay_cat_004735.jpg
#   inflating: cat_136/pixabay_cat_004736.jpg
#   inflating: cat_136/pixabay_cat_004737.jpg
#   inflating: cat_136/pixabay_cat_004738.jpg
#   inflating: cat_136/pixabay_cat_004739.jpg
#   inflating: cat_136/pixabay_cat_004740.jpg
#   inflating: cat_136/pixabay_cat_004741.jpg
#   inflating: cat_136/pixabay_cat_004742.jpg
#   inflating: cat_136/pixabay_cat_004743.jpg
#   inflating: cat_136/pixabay_cat_004744.jpg
#   inflating: cat_136/pixabay_cat_004745.jpg
#   inflating: cat_136/pixabay_cat_004746.jpg
#   inflating: cat_136/pixabay_cat_004747.jpg
#   inflating: cat_136/pixabay_cat_004748.jpg
#   inflating: cat_136/pixabay_cat_004749.jpg
#   inflating: cat_136/pixabay_cat_004750.jpg
#   inflating: cat_136/pixabay_cat_004751.jpg
#   inflating: cat_136/pixabay_cat_004752.jpg
#   inflating: cat_136/pixabay_cat_004753.jpg
#   inflating: cat_136/pixabay_cat_004754.jpg
#   inflating: cat_136/pixabay_cat_004755.jpg
#   inflating: cat_136/pixabay_cat_004756.jpg
#   inflating: cat_136/pixabay_cat_004757.jpg
#   inflating: cat_136/pixabay_cat_004758.jpg
#   inflating: cat_136/pixabay_cat_004760.jpg
#   inflating: cat_136/pixabay_cat_004761.jpg
#   inflating: cat_136/pixabay_cat_004762.jpg
#   inflating: cat_136/pixabay_cat_004763.jpg
#   inflating: cat_136/pixabay_cat_004764.jpg
#   inflating: cat_136/pixabay_cat_004767.jpg
#   inflating: cat_136/pixabay_cat_004768.jpg
#   inflating: cat_136/pixabay_cat_004769.jpg
#   inflating: cat_136/pixabay_cat_004770.jpg
#   inflating: cat_136/pixabay_cat_004771.jpg
#   inflating: cat_136/pixabay_cat_004772.jpg
#   inflating: cat_136/pixabay_cat_004773.jpg
#   inflating: cat_136/pixabay_cat_004774.jpg
#   inflating: cat_136/pixabay_cat_004775.jpg
#   inflating: cat_136/pixabay_cat_004776.jpg
#   inflating: cat_136/pixabay_cat_004777.jpg
#   inflating: cat_136/pixabay_cat_004778.jpg
#   inflating: cat_136/pixabay_cat_004779.jpg
#   inflating: cat_136/pixabay_cat_004780.jpg
#   inflating: cat_136/pixabay_cat_004781.jpg
#   inflating: cat_136/pixabay_cat_004785.jpg
#   inflating: cat_136/pixabay_cat_004786.jpg
#   inflating: cat_136/pixabay_cat_004787.jpg
#   inflating: cat_136/pixabay_cat_004788.jpg
#   inflating: cat_136/pixabay_cat_004789.jpg
#   inflating: cat_136/pixabay_cat_004790.jpg
#   inflating: cat_136/pixabay_cat_004791.jpg
#   inflating: cat_136/pixabay_cat_004792.jpg
#   inflating: cat_136/pixabay_cat_004794.jpg
#   inflating: cat_136/pixabay_cat_004795.jpg
#   inflating: cat_136/pixabay_cat_004796.jpg
#   inflating: cat_136/pixabay_cat_004797.jpg
#   inflating: cat_136/pixabay_cat_004798.jpg
#   inflating: cat_136/pixabay_cat_004799.jpg
#   inflating: cat_136/pixabay_cat_004800.jpg
#   inflating: cat_136/pixabay_cat_004801.jpg
#   inflating: cat_136/pixabay_cat_004802.jpg
#   inflating: cat_136/pixabay_cat_004803.jpg
#   inflating: cat_136/pixabay_cat_004804.jpg
#   inflating: cat_136/pixabay_cat_004805.jpg
#   inflating: cat_136/pixabay_cat_004806.jpg
#   inflating: cat_136/pixabay_cat_004807.jpg
#   inflating: cat_136/pixabay_cat_004809.jpg
#   inflating: cat_136/pixabay_cat_004810.jpg
#   inflating: cat_136/pixabay_cat_004811.jpg
#   inflating: cat_136/pixabay_cat_004812.jpg
#   inflating: cat_136/pixabay_cat_004813.jpg
#   inflating: cat_136/pixabay_cat_004814.jpg
#   inflating: cat_136/pixabay_cat_004815.jpg
#   inflating: cat_136/pixabay_cat_004817.jpg
#   inflating: cat_136/pixabay_cat_004818.jpg
#   inflating: cat_136/pixabay_cat_004819.jpg
#   inflating: cat_136/pixabay_cat_004820.jpg
#   inflating: cat_136/pixabay_cat_004821.jpg
#   inflating: cat_136/pixabay_cat_004822.jpg
#   inflating: cat_136/pixabay_cat_004823.jpg
#   inflating: cat_136/pixabay_cat_004824.jpg
#   inflating: cat_136/pixabay_cat_004825.jpg
#   inflating: cat_136/pixabay_cat_004827.jpg
#   inflating: cat_136/pixabay_cat_004828.jpg
#   inflating: cat_136/pixabay_cat_004829.jpg
#   inflating: cat_136/pixabay_cat_004830.jpg
#   inflating: cat_136/pixabay_cat_004831.jpg
#   inflating: cat_136/pixabay_cat_004833.jpg
#   inflating: cat_136/pixabay_cat_004834.jpg

# %%
class CatDataset(Dataset):
    """Dataset for cats.
    Read images from disk, convert them to a torch tensor, and resize them to equal squares.

    :path_to_dataset str: path to directory with images
    :size int: size of output images
    """

    def __init__(self, path_to_dataset: str = "cat_136", size: int = 64, crop_rate: int = 32):
        self.path_base = path_to_dataset
        self.size = size
        self.crop_rate = crop_rate
        self.photo_names = listdir(path_to_dataset)
        print(f"Found {len(self.photo_names)} images")

    def __getitem__(self, index: int) -> torch.Tensor:
        """Load image from disk and prepare for training.

        :index int: index of image to load
        :return Tensor: torch Tensor with image, shape: [3; self.size; self.size]
        """
        # 1. Load image from disk, create Tensor
        image_path = path.join(self.path_base, self.photo_names[index])
        with Image.open(image_path) as img:
            data = np.array(img)  # 136 x 136 x 3
            width, height = data.shape[0], data.shape[1]
        image = torch.from_numpy(data)

        # 2. Random cropping to make images more varied:
        #    1. Generate crop for X and Y axis from 0 to self.crop_rate
        #    2. Cut cropped parts from image -- tensor slicing
        l, r, b, h = torch.randint(0, self.crop_rate, (4, ))

        image_sl = image[l : width - r, b : height - h]

        # 3. Make the image of the required size via F.interpolate
        #    - Channels should be the first dimmension, so transpose 0 and 2 dim
        #    - Interpolate accepts batched input, use `unsqueeze` ans `squeeze` to add and remove dim
        image_sl = image_sl.transpose(0, 2)
        image_sl = image_sl.unsqueeze(0)
        image_sl = F.interpolate(image_sl, size=[self.size, self.size])
        image_sl = image_sl.squeeze(0)

        # 4. Normalize image to be in range [-1; 1] instead of [0; 255]
        image_sl = image_sl / (255 / 2) - 1

        return image_sl

    def __len__(self) -> int:
        """Return size of dataset

        :return int: size of dataset
        """
        return len(self.photo_names)

# %%
dataset = CatDataset(size=64)
random_images = torch.stack([dataset[i] for i in [3, 15, 182, 592, 394, 2941]], dim=0)
assert list(random_images.shape) == [
    6,
    3,
    64,
    64,
], f"Icorrect shape of images: {random_images[0].shape}, should be [3, 64, 64]"
assert all([-1.0 <= it <= 1.0 for it in random_images.flatten()]), f"Incorrect image normalization"

visualize_images(random_images)
# Out:
# Found 5153 images

# %% [markdown]
# ## Модель
# Для генерации котов реализуем нейронную сеть типа **GAN**, а именно: **DCGAN**. Модели этого типа состоят из 2 отдельных блоков: генератор и дискриминатор.
# Цель генератора — это по случайному шуму генерировать картинку, а дискриминатора — отличать сгенерированную от настоящей.
# Каждый блок — это отдельная нейронная сеть, а их выход используется в качестве функции потери у другой!
#
# ### Генератор
#
# Для начала реализуем генератор. Предлагается использовать следующую архитектуру:
#
# ![image.png](data:image/png;base64,...)![](/content/imgs/DCGAN.png)
#
# Для ее реализации вам потребуются модули `nn.BatchNorm2d`, `nn.Conv2d`, `nn.ConvTranspose2D`, `nn.ReLU`.

# %%
def random_noise(batch_size: int, channels: int, side_size: int, *, device: torch.device = None) -> torch.Tensor:
    """Generate random noise for batch of images with given size and number of channels."""
    return torch.randn(batch_size, channels, side_size, side_size, device=device)


class Generator(nn.Module):
    """Neural network to generate image from noise

    :start_size int: size of randomized image
    :latent_size int: size of latent size, i.e. number of channels in randomized images
    :upsampling int: number of layers
    :start_channels int: number of hidden channels, reduced by 2 in each block
    """

    def __init__(self, start_size: int = 2, latent_size: int = 32, upsamplings: int = 6, start_channels: int = 1024):
        super().__init__()
        self.start_size = start_size
        self.latent_size = latent_size
        self.start_channels = start_channels
        self.upsamplings = upsamplings

        self.generator = nn.Sequential(*self.get_modules())

    def get_modules(self) -> list[nn.Module]:
        """Create list of modules for specified hyperparameters

        :return list: list of modules
        """
        latent_channels = self.start_channels
        modules = []
        modules.append(nn.Conv2d(in_channels=self.latent_size, out_channels=self.start_channels,
                                kernel_size=1, stride=1, padding=0))

        for _ in range(self.upsamplings):
            modules.append(nn.ConvTranspose2d(in_channels=latent_channels,
                                             out_channels = latent_channels // 2,
                                             kernel_size = 4,
                                             stride = 2, padding = 1))
            latent_channels //= 2

            modules.append(nn.BatchNorm2d(num_features=latent_channels))
            modules.append(nn.ReLU())

        modules.append(nn.Conv2d(in_channels=latent_channels, out_channels=3,
                                kernel_size = 1, stride = 1, padding = 0))
        modules.append(nn.Tanh())

        return modules


    @property
    def device(self):
        return next(self.parameters()).device

    def forward(self, batch_size: int) -> torch.Tensor:
        """Generate batch of faked images

        :batch_size int: number of images to generate
        :return Tensor: Tensor w/ generated images, shape [batch size; 3; end size; end size]
        """
        # 1. Generate random noise of starting shape via `random_noise` func
        r_noise = random_noise(batch_size, self.latent_size, self.start_size, device=self.device)
        # 2. Generate random images
        images = self.generator(r_noise)
        return images

# %% [markdown]
# ### Дискриминатор
# Теперь реализуем дискриминатор, его задача по картинке предсказывать 1 класс -- реальное или фейковое изображение.
#
# Предлагается использовать следующую архитектуру:
#
# ![](https://github.com/SpirinEgor/HSE.machine_learning/blob/main/06.%20This%20Cat%20Does%20Not%20Exist/imgs/Disc_DCGAN.png?raw=1)
#
# Для ее реализации вам потребуются модули `nn.BatchNorm2d`, `nn.Conv2d`, `nn.ReLU` и `nn.Sigmoid`.

# %%
class Discriminator(nn.Module):
    """Neural network to classify image

    :downsamplings int: number of layers
    :start_channels int: number of hidden channels, increased by 2 in each block
    """

    def __init__(self, downsamplings: int = 6, start_channels: int = 8, size: int = 128):
        super().__init__()
        self.downsamplings = downsamplings
        self.start_channels = start_channels
        self.size = size


        self.discriminator = nn.Sequential(*self.get_modules())

    def get_modules(self) -> list[nn.Module]:
        """Create list of modules for specified hyperparameters

        :return list: list of modules
        """
        modules = []
        c = self.start_channels
        modules.append(nn.Conv2d(in_channels=3, out_channels=c, kernel_size=1, stride=1, padding=0))

        for _ in range(self.downsamplings):
            modules.append(nn.Conv2d(in_channels=c, out_channels=c*2, kernel_size=3, stride=2, padding=1))
            modules.append(nn.BatchNorm2d(num_features=c*2))
            modules.append(nn.ReLU())
            c *= 2

        modules.append(nn.Flatten())

        h = b = self.size // 2 ** self.downsamplings

        modules.append(nn.Linear(in_features=c * b * h, out_features=1))
        modules.append(nn.Sigmoid())

        return modules


    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """Predict class for images

        :x Tensor: input batch of images, shape [batch size; 3; H; W]
        :return Tensor: output batch of probabilities, shape [batch size; 1]
        """

        probabilities = self.discriminator(x)
        return probabilities

# %% [markdown]
# ## Обучение
#
# Будем обучать GAN несколько эпох, при этом каждый шаг обучения состоит из 3 действий:
# 1. Позитивный шаг для дискриминатора: используем реальные картинки
# 2. Негативный шаг для дискриминатора: используем сгенерированные картинки
# 3. Шаг генератора: генерируем картинки, считаем предсказания дискриминатора, используем для обновления генератора.
#
# Во время обучения будем следить за лоссом и дискриминатора, и генератора. При этом тренд лоссов будет немного необычным: сначала будет обучаться дискриминатор, как только он начнет улавливать суть изображений, то и генератор станет обучаться. Однако чем качественнее генератор создает картинки, тем сложнее дискриминатору их различить и его лосс начинает расти.

# %%
class GANTrainer:
    """Trainer for basic GAN on specified dataset"""

    def __init__(self, generator, discriminator, dataset, device):
        self.generator = generator.to(device)
        self.discriminator = discriminator.to(device)
        self.dataset = dataset

        self.device = device

    def configure_optimizers(
        self, learning_rate: float, weight_decay: float = 1e-2, betas: tuple[float] = (0.5, 0.999)
    ) -> tuple[Optimizer]:
        """Create SEPARATE AdamW optimizers for generator and discriminator.
        Input arguments are for torch.optim.AdamW optimizers.

        :return tuple: optimizer for generator, optimizer for discriminator
        """
        gen_opt = torch.optim.AdamW(params=self.generator.parameters(),
                                    lr=learning_rate,
                                    weight_decay=weight_decay,
                                    betas=betas)
        discr_opt = torch.optim.AdamW(params=self.discriminator.parameters(),
                                    lr=learning_rate,
                                    weight_decay=weight_decay,
                                    betas=betas)
        return gen_opt, discr_opt

    def configure_dataloader(self, batch_size: int, shuffle: bool) -> DataLoader:
        """Create dataloader for dataset with specified batch size"""
        return DataLoader(self.dataset, batch_size, shuffle)

    def discriminator_update(self, batch: torch.Tensor, disc_optim: Optimizer, is_positive: bool) -> float:
        """Update step for discriminator

        :batch Tensor: tensor of images for training, shape: [bs; 3; H; W]
        :disc_optim Optimizer: Optimizer for Discriminator
        :is_positive bool: whether batch of images is fake or real
        :return float: loss on passed batch
        """
        # 1. Set gradients to zero
        disc_optim.zero_grad()

        # 2. Make predictions
        predicts = self.discriminator(batch)

        # 3. Create target values based on `is_positive`
        #    If the batch is fake, all labels will be zeros, otherwise - ones.
        targets = torch.full_like(predicts, int(is_positive))

        # 4. Calculate loss based on F.binary_cross_entropy
        loss = F.binary_cross_entropy(predicts, targets)

        # 5. Calculate gradients
        loss.backward()

        # 6. Update weights
        disc_optim.step()

        # 7. Convert loss to float
        loss = loss.item()
        return loss

    def generator_update(self, batch_size: int, gen_optim: Optimizer) -> float:
        """Update step for generator

        :batch_size int: Number of images to generate for training
        :gen_optim Optimizer: Optimizer for Generator
        :return float: loss on passed batch
        """
        # 1. Set gradients to zero
        gen_optim.zero_grad()

        # 2. Generate images
        images = self.generator(batch_size)

        # 3. Predict image classes:
        predicts = self.discriminator(images)

        # 4. Create target values: we want to trick discrimator
        #    - all fake images should be classified as real
        targets = torch.ones_like(predicts)

        # 5. Calculate loss based on F.binary_cross_entropy
        loss = F.binary_cross_entropy(predicts, targets)

        # 6. Calculate gradients
        loss.backward()

        # 7. Update weights
        gen_optim.step()

        # 8. Convert loss to float
        loss = loss.item()
        return loss

    def run_epoch(self, dataloader, gen_optim, disc_optim) -> tuple[float, float]:
        gen_loss_mean, disc_loss_mean = 0.0, 0.0

        for batch in tqdm(dataloader):
            batch = batch.to(self.device, non_blocking=True)

            # Positive update
            disc_loss_mean += self.discriminator_update(batch, disc_optim, is_positive=True)

            # Negative update
            with torch.no_grad():
                fake_batch = self.generator(batch.shape[0])
            disc_loss_mean += self.discriminator_update(fake_batch, disc_optim, is_positive=False)

            # Generator update
            gen_loss_mean += self.generator_update(batch.shape[0], gen_optim)

        gen_loss_mean /= len(dataloader)
        disc_loss_mean /= len(dataloader)
        return gen_loss_mean, disc_loss_mean

    def train(
        self, n_epochs: int = 50, batch_size: int = 8, learning_rate: float = 1e-4, visualize_every_epoch: int = 10
    ):
        gen_optim, disc_optim = self.configure_optimizers(learning_rate)
        dataloader = self.configure_dataloader(batch_size, shuffle=True)

        for epoch in range(n_epochs):
            gen_loss_mean, disc_loss_mean = self.run_epoch(dataloader, gen_optim, disc_optim)

            if (epoch + 1) % visualize_every_epoch == 0:
                with torch.no_grad():
                    fake_images = self.generator(6)
                visualize_images(fake_images, rows=2)

            print(f"Epoch {epoch+1} | Discriminator loss: {disc_loss_mean:.4f} | Generator loss: {gen_loss_mean:.4f}")

# %%
generator = Generator()
discriminator = Discriminator()
dataset = CatDataset(size=128)

trainer = GANTrainer(generator, discriminator, dataset, device)
# Out:
# Found 5153 images

# %%
trainer.train(n_epochs=50, batch_size=8, visualize_every_epoch=10)
# Out:
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 1 | Discriminator loss: 0.1654 | Generator loss: 5.3079
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 2 | Discriminator loss: 0.1711 | Generator loss: 5.4907
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 3 | Discriminator loss: 0.8385 | Generator loss: 2.6387
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 4 | Discriminator loss: 0.9129 | Generator loss: 2.3154
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 5 | Discriminator loss: 1.0885 | Generator loss: 1.8658
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 6 | Discriminator loss: 1.0344 | Generator loss: 1.9148
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 7 | Discriminator loss: 1.0290 | Generator loss: 1.8137
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 8 | Discriminator loss: 1.0347 | Generator loss: 1.6792
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 9 | Discriminator loss: 1.0073 | Generator loss: 1.7347
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 10 | Discriminator loss: 0.9924 | Generator loss: 1.7390
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 11 | Discriminator loss: 0.9415 | Generator loss: 1.7878
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 12 | Discriminator loss: 0.8807 | Generator loss: 1.9454
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 13 | Discriminator loss: 0.8289 | Generator loss: 2.1354
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 14 | Discriminator loss: 0.7730 | Generator loss: 2.1299
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 15 | Discriminator loss: 0.7614 | Generator loss: 2.2359
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 16 | Discriminator loss: 0.7022 | Generator loss: 2.3942
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 17 | Discriminator loss: 0.6596 | Generator loss: 2.4195
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 18 | Discriminator loss: 0.6646 | Generator loss: 2.5954
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 19 | Discriminator loss: 0.6418 | Generator loss: 2.5167
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 20 | Discriminator loss: 0.6285 | Generator loss: 2.6338
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 21 | Discriminator loss: 0.6328 | Generator loss: 2.7347
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 22 | Discriminator loss: 0.6282 | Generator loss: 2.5734
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 23 | Discriminator loss: 0.6174 | Generator loss: 2.6912
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 24 | Discriminator loss: 0.6089 | Generator loss: 2.6843
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 25 | Discriminator loss: 0.6182 | Generator loss: 2.7024
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 26 | Discriminator loss: 0.5571 | Generator loss: 2.7656
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 27 | Discriminator loss: 0.5592 | Generator loss: 2.9230
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 28 | Discriminator loss: 0.5424 | Generator loss: 3.0169
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 29 | Discriminator loss: 0.5254 | Generator loss: 3.0219
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 30 | Discriminator loss: 0.5322 | Generator loss: 3.0445
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 31 | Discriminator loss: 0.5374 | Generator loss: 3.0128
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 32 | Discriminator loss: 0.5111 | Generator loss: 3.1261
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 33 | Discriminator loss: 0.4878 | Generator loss: 3.1159
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 34 | Discriminator loss: 0.4911 | Generator loss: 3.2039
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 35 | Discriminator loss: 0.4872 | Generator loss: 3.2373
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 36 | Discriminator loss: 0.4673 | Generator loss: 3.2827
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 37 | Discriminator loss: 0.4729 | Generator loss: 3.3954
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 38 | Discriminator loss: 0.4363 | Generator loss: 3.3171
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 39 | Discriminator loss: 0.4681 | Generator loss: 3.2985
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 40 | Discriminator loss: 0.4279 | Generator loss: 3.3496
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 41 | Discriminator loss: 0.4441 | Generator loss: 3.5233
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 42 | Discriminator loss: 0.4396 | Generator loss: 3.3401
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 43 | Discriminator loss: 0.3926 | Generator loss: 3.5687
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 44 | Discriminator loss: 0.4363 | Generator loss: 3.3966
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 45 | Discriminator loss: 0.4202 | Generator loss: 3.5247
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 46 | Discriminator loss: 0.4262 | Generator loss: 3.6128
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 47 | Discriminator loss: 0.4116 | Generator loss: 3.5788
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 48 | Discriminator loss: 0.4124 | Generator loss: 3.6006
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 49 | Discriminator loss: 0.4054 | Generator loss: 3.6006
#   0%|          | 0/645 [00:00<?, ?it/s]
# Epoch 50 | Discriminator loss: 0.4003 | Generator loss: 3.5808

# %% [markdown]
# ## Сохранение модели
#
# После обучения модели необходимо сохранить модель, создадим общий чекпоинт с дискриминатором и генератором.
#
# Для этого будут полезны метод `state_dict` у любого модуля в Torch и функция `torch.save`.

# %%
def dump_checkpoint(generator: Generator, discriminator: Discriminator, filename: str):
    """Save modules to specified file.
    Checkpoint contains dict with state dicts for Generator and Discriminator along with their hyperparameters.
    """
    checkpoint = {
        'gen_state_dict': generator.state_dict(),
        'gen_hyperparams': {
            'start_size': generator.start_size,
            'latent_size': generator.latent_size,
            'upsamplings': generator.upsamplings,
            'start_channels': generator.start_channels
        },
        'discr_state_dict': discriminator.state_dict(),
        'discr_hyperparams': {
            'downsamplings': discriminator.downsamplings,
            'start_channels': discriminator.start_channels,
            'size': discriminator.size
        }
    }

    torch.save(checkpoint, filename)

    print(f"Checkpoint saved to file {filename}")

# %%
dump_checkpoint(generator, discriminator, "checkpoint.pt")
# Out:
# Checkpoint saved to file checkpoint.pt

# %% [markdown]
# # Загрузка модели
#
# Проверим, что модель загружается с диска и работает.
#
# Для этого будут полезны методы `load_state_dict` у любого модуля в Torch и функция `torch.load`.

# %%
def load_checkpoint(filename: str) -> tuple[Generator, Discriminator]:
    """Load modules from specified file."""
    # 1. Load checkpoint from specified filename
    checkpoint = torch.load(filename, weights_only=True)
    # 2. Init Generator with hyperparameters from checkpoint
    generator = Generator(**checkpoint['gen_hyperparams'])
    # 3. Load state dict for Generator
    gen_state_dict = checkpoint['gen_state_dict']
    generator.load_state_dict(gen_state_dict)
    # 4. Init Discriminator with hyperparameters from checkpoint
    dicriminator = Discriminator(**checkpoint['discr_hyperparams'])
    # 5. Load state dict for Discriminator
    discr_state_dict = checkpoint['discr_state_dict']
    dicriminator.load_state_dict(discr_state_dict)

    return generator, discriminator

# %%
generator, discriminator = load_checkpoint("checkpoint.pt")
generator = generator.to(device)
discriminator = discriminator.to(device)

# %%
with torch.inference_mode():
    fake_images = generator(6)
    probs = discriminator(fake_images)
    prediction = [["FAKE", "REAL"][i > 0.5] for i in probs]

print(f"Predicted classes: {', '.join(prediction)}")
visualize_images(fake_images)
# Out:
# Predicted classes: REAL, REAL, REAL, REAL, REAL, REAL

# %% [markdown]
# При сдаче практики также прикрепите полученный чекпоинт!
